# %% [markdown]
# **import Module**

# %%
import csv
import numpy as np

# %% [markdown]
# **Open CSV File**

# %%
with open("amazon_sales_dataset.csv") as file:
    reader = csv.reader(file)
    data = list(reader)

# %% [markdown]
# **Remove the header row**

# %%
data = data[1:]
data
# Out:
# [['OD1000', 'P500', 'Grocery', '122', '4', '20', '1.7'],
#  ['OD1001', 'P501', 'Electronics', '45232', '5', '30', '2.8'],
#  ['OD1002', 'P502', 'Grocery', '234', '3', '10', '4.5'],
#  ['OD1003', 'P503', 'Fashion', '330', '5', '5', '3.9'],
#  ['OD1004', 'P504', 'Electronics', '2933', '4', '20', '3.5'],
#  ['OD1005', 'P505', 'Home', '19869', '5', '15', '1.1'],
#  ['OD1006', 'P506', 'Electronics', '41934', '3', '30', '1.6'],
#  ['OD1007', 'P507', 'Electronics', '3247', '3', '15', '3.1'],
#  ['OD1008', 'P508', 'Fashion', '1728', '3', '20', '3.4'],
#  ['OD1009', 'P509', 'Grocery', '40', '1', '30', '1.1'],
#  ['OD1010', 'P510', 'Fashion', '800', '4', '25', '4.2'],
#  ['OD1011', 'P511', 'Grocery', '796', '2', '20', '1.9'],
#  ['OD1012', 'P512', 'Grocery', '111', '4', '30', '3.4'],
#  ['OD1013', 'P513', 'Grocery', '795', '3', '25', '2.6'],
#  ['OD1014', 'P514', 'Books', '660', '4', '5', '2.7'],
#  ['OD1015', 'P515', 'Electronics', '44073', '2', '15', '1.7'],
#  ['OD1016', 'P516', 'Home', '13090', '2', '5', '2.8'],
#  ['OD1017', 'P517', 'Fashion', '401', '4', '25', '3.9'],
#  ['OD1018', 'P518', 'Electronics', '12034', '4', '0', '4.8'],
#  ['OD1019', 'P519', 'Books', '823', '5', '5', '3.2'],
#  ['OD1020', 'P520', 'Home', '12285', '1', '15', '3.4'],
#  ['OD1021', 'P521', 'Fashion', '692', '1', '20', '4.2'],
#  ['OD1022', 'P522', 'Electronics', '49716', '1', '30', '2.7'],
#  ['OD1023', 'P523', 'Electronics', '2527', '3', '10', '3.8'],
#  ['OD1024', 'P524', 'Fashion', '1898', '3', '0', '3.4'],
#  ['OD1025', 'P525', 'Beauty', '2328', '2', '0', '4.7'],
#  ['OD1026', 'P526', 'Fashion', '400', '4', '5', '1.4'],
#  ['OD1027', 'P527', 'Grocery', '522', '5', '10', '3.4'],
#  ['OD1028', 'P528', 'Electronics', '11465', '3', '10', '2.9'],
#  ['OD1029', 'P529', 'Electronics', '48216', '3', '0', '3.9'],
#  ['OD1030', 'P530', 'Fashion', '702', '3', '0', '3.8'],
#  ['OD1031', 'P531', 'Grocery', '877', '2', '15', '1.4'],
#  ['OD1032', 'P532', 'Electronics', '49202', '1', '15', '3.3'],
#  ['OD1033', 'P533', 'Fashion', '2123', '5', '30', '3.4'],
#  ['OD1034', 'P534', 'Electronics', '2178', '3', '20', '1.9'],
#  ['OD1035', 'P535', 'Fashion', '1383', '3', '10', '1.6'],
#  ['OD1036', 'P536', 'Books', '676', '2', '20', '2.2'],
#  ['OD1037', 'P537', 'Home', '11352', '4', '15', '1.9'],
#  ['OD1038', 'P538', 'Grocery', '359', '3', '5', '1.5'],
#  ['OD1039', 'P539', 'Fashion', '1696', '1', '0', '1.9'],
#  ['OD1040', 'P540', 'Electronics', '7276', '4', '20', '4.4'],
#  ['OD1041', 'P541', 'Grocery', '378', '3', '0', '2.9'],
#  ['OD1042', 'P542', 'Grocery', '244', '3', '5', '2.4'],
#  ['OD1043', 'P543', 'Books', '925', '1', '15', '2.5'],
#  ['OD1044', 'P544', 'Home', '13908', '2', '15', '2.0'],
#  ['OD1045', 'P545', 'Fashion', '1836', '1', '0', '2.1'],
#  ['OD1046', 'P546', 'Grocery', '21', '2', '15', '1.2'],
#  ['OD1047', 'P547', 'Fashion', '1959', '1', '0', '2.0'],
#  ['OD1048', 'P548', 'Books', '228', '5', '15', '2.8'],
#  ['OD1049', 'P549', 'Beauty', '1783', '4', '30', '4.0'],
#  ['OD1050', 'P550', 'Fashion', '322', '1', '30', '4.2'],
#  ['OD1051', 'P551', 'Fashion', '397', '3', '30', '1.4'],
#  ['OD1052', 'P552', 'Home', '9439', '3', '25', '3.8'],
#  ['OD1053', 'P553', 'Books', '869', '4', '15', '3.7'],
#  ['OD1054', 'P554', 'Fashion', '2650', '2', '10', '4.2'],
#  ['OD1055', 'P555', 'Electronics', '11911', '4', '0', '3.8'],
#  ['OD1056', 'P556', 'Fashion', '1863', '2', '0', '3.7'],
#  ['OD1057', 'P557', 'Electronics', '8620', '1', '5', '4.7'],
#  ['OD1058', 'P558', 'Books', '396', '3', '30', '3.6'],
#  ['OD1059', 'P559', 'Electronics', '31565', '1', '15', '3.1'],
#  ['OD1060', 'P560', 'Home', '2149', '1', '25', '4.6'],
#  ['OD1061', 'P561', 'Electronics', '30355', '3', '30', '2.4'],
#  ['OD1062', 'P562', 'Grocery', '118', '3', '10', '4.4'],
#  ['OD1063', 'P563', 'Beauty', '2151', '1', '15', '1.3'],
#  ['OD1064', 'P564', 'Grocery', '987', '4', '25', '3.7'],
#  ['OD1065', 'P565', 'Fashion', '453', '3', '25', '4.8'],
#  ['OD1066', 'P566', 'Beauty', '2250', '5', '5', '1.6'],
#  ['OD1067', 'P567', 'Books', '436', '2', '25', '2.8'],
#  ['OD1068', 'P568', 'Electronics', '47260', '4', '0', '1.1'],
#  ['OD1069', 'P569', 'Electronics', '26376', '4', '30', '3.9'],
#  ['OD1070', 'P570', 'Home', '4835', '1', '15', '3.0'],
#  ['OD1071', 'P571', 'Grocery', '489', '5', '10', '4.6'],
#  ['OD1072', 'P572', 'Grocery', '302', '3', '5', '2.4'],
#  ['OD1073', 'P573', 'Fashion', '2531', '1', '20', '1.9'],
#  ['OD1074', 'P574', 'Home', '9107', '3', '15', '1.1'],
#  ['OD1075', 'P575', 'Electronics', '44580', '1', '15', '4.8'],
#  ['OD1076', 'P576', 'Electronics', '43984', '5', '25', '2.5'],
#  ['OD1077', 'P577', 'Electronics', '34328', '5', '0', '3.2'],
#  ['OD1078', 'P578', 'Fashion', '806', '3', '15', '4.4'],
#  ['OD1079', 'P579', 'Home', '290', '5', '20', '1.8'],
#  ['OD1080', 'P580', 'Electronics', '20278', '2', '0', '2.6'],
#  ['OD1081', 'P581', 'Home', '669', '3', '25', '1.4'],
#  ['OD1082', 'P582', 'Home', '7555', '2', '30', '3.1'],
#  ['OD1083', 'P583', 'Electronics', '34677', '2', '0', '4.4'],
#  ['OD1084', 'P584', 'Home', '7660', '3', '25', '2.4'],
#  ['OD1085', 'P585', 'Electronics', '6301', '2', '10', '2.0'],
#  ['OD1086', 'P586', 'Fashion', '2655', '5', '15', '3.0'],
#  ['OD1087', 'P587', 'Fashion', '235', '5', '15', '3.6'],
#  ['OD1088', 'P588', 'Electronics', '7155', '4', '10', '2.4'],
#  ['OD1089', 'P589', 'Electronics', '13903', '2', '5', '2.8'],
#  ['OD1090', 'P590', 'Books', '952', '3', '0', '1.6'],
#  ['OD1091', 'P591', 'Fashion', '1348', '2', '5', '1.1'],
#  ['OD1092', 'P592', 'Electronics', '43175', '2', '25', '2.2'],
#  ['OD1093', 'P593', 'Electronics', '15838', '4', '20', '3.1'],
#  ['OD1094', 'P594', 'Fashion', '1795', '4', '15', '3.5'],
#  ['OD1095', 'P595', 'Electronics', '22199', '5', '15', '2.6'],
#  ['OD1096', 'P596', 'Home', '15302', '4', '20', '4.9'],
#  ['OD1097', 'P597', 'Fashion', '1329', '3', '0', '2.6'],
#  ['OD1098', 'P598', 'Electronics', '14598', '4', '5', '1.3'],
#  ['OD1099', 'P599', 'Fashion', '940', '2', '20', '1.3'],
#  ['OD1100', 'P600', 'Fashion', '1350', '1', '15', '2.6'],
#  ['OD1101', 'P601', 'Grocery', '77', '2', '0', '2.8'],
#  ['OD1102', 'P602', 'Electronics', '46675', '1', '20', '2.1'],
#  ['OD1103', 'P603', 'Beauty', '1262', '5', '25', '3.9'],
#  ['OD1104', 'P604', 'Beauty', '203', '3', '20', '1.5'],
#  ['OD1105', 'P605', 'Home', '9535', '5', '30', '1.2'],
#  ['OD1106', 'P606', 'Electronics', '30945', '4', '20', '2.9'],
#  ['OD1107', 'P607', 'Electronics', '43725', '2', '20', '2.9'],
#  ['OD1108', 'P608', 'Electronics', '37720', '2', '5', '4.8'],
#  ['OD1109', 'P609', 'Fashion', '2689', '1', '20', '3.7'],
#  ['OD1110', 'P610', 'Grocery', '35', '2', '0', '4.5'],
#  ['OD1111', 'P611', 'Grocery', '179', '3', '15', '3.3'],
#  ['OD1112', 'P612', 'Books', '788', '3', '15', '1.5'],
#  ['OD1113', 'P613', 'Home', '5152', '3', '10', '4.8'],
#  ['OD1114', 'P614', 'Books', '933', '1', '0', '3.6'],
#  ['OD1115', 'P615', 'Fashion', '1266', '4', '20', '1.3'],
#  ['OD1116', 'P616', 'Home', '5826', '2', '20', '1.4'],
#  ['OD1117', 'P617', 'Electronics', '35350', '1', '5', '2.3'],
#  ['OD1118', 'P618', 'Fashion', '1825', '2', '10', '2.1'],
#  ['OD1119', 'P619', 'Home', '3367', '2', '20', '2.4'],
#  ['OD1120', 'P620', 'Electronics', '11838', '5', '15', '2.7'],
#  ['OD1121', 'P621', 'Electronics', '24048', '1', '15', '1.7'],
#  ['OD1122', 'P622', 'Books', '555', '3', '0', '3.9'],
#  ['OD1123', 'P623', 'Grocery', '567', '2', '0', '4.1'],
#  ['OD1124', 'P624', 'Beauty', '1737', '5', '15', '2.7'],
#  ['OD1125', 'P625', 'Fashion', '1748', '1', '10', '1.4'],
#  ['OD1126', 'P626', 'Books', '371', '1', '25', '3.0'],
#  ['OD1127', 'P627', 'Electronics', '1228', '5', '10', '1.4'],
#  ['OD1128', 'P628', 'Electronics', '14423', '4', '20', '4.6'],
#  ['OD1129', 'P629', 'Grocery', '95', '1', '30', '4.8'],
#  ['OD1130', 'P630', 'Fashion', '2982', '4', '10', '3.0'],
#  ['OD1131', 'P631', 'Home', '8435', '5', '20', '2.2'],
#  ['OD1132', 'P632', 'Electronics', '24076', '4', '10', '1.9'],
#  ['OD1133', 'P633', 'Home', '1267', '1', '30', '1.4'],
#  ['OD1134', 'P634', 'Grocery', '61', '2', '30', '5.0'],
#  ['OD1135', 'P635', 'Electronics', '37997', '5', '10', '4.6'],
#  ['OD1136', 'P636', 'Electronics', '37598', '3', '5', '4.9'],
#  ['OD1137', 'P637', 'Beauty', '1003', '4', '0', '1.4'],
#  ['OD1138', 'P638', 'Electronics', '2042', '5', '5', '2.6'],
#  ['OD1139', 'P639', 'Electronics', '23822', '2', '5', '1.3'],
#  ['OD1140', 'P640', 'Electronics', '27462', '5', '0', '4.5'],
#  ['OD1141', 'P641', 'Grocery', '676', '1', '20', '4.0'],
#  ['OD1142', 'P642', 'Books', '168', '4', '30', '2.9'],
#  ['OD1143', 'P643', 'Home', '19407', '3', '5', '4.6'],
#  ['OD1144', 'P644', 'Books', '137', '3', '20', '1.0'],
#  ['OD1145', 'P645', 'Beauty', '1293', '2', '15', '1.5'],
#  ['OD1146', 'P646', 'Fashion', '1028', '1', '30', '4.0'],
#  ['OD1147', 'P647', 'Electronics', '43456', '4', '25', '2.6'],
#  ['OD1148', 'P648', 'Electronics', '34799', '1', '0', '4.5'],
#  ['OD1149', 'P649', 'Home', '5129', '5', '25', '4.2'],
#  ['OD1150', 'P650', 'Electronics', '46240', '5', '20', '2.3'],
#  ['OD1151', 'P651', 'Electronics', '21059', '5', '10', '4.7'],
#  ['OD1152', 'P652', 'Beauty', '1749', '3', '10', '4.9'],
#  ['OD1153', 'P653', 'Fashion', '2294', '1', '0', '3.8'],
#  ['OD1154', 'P654', 'Fashion', '1596', '3', '30', '1.2'],
#  ['OD1155', 'P655', 'Books', '110', '2', '25', '2.8'],
#  ['OD1156', 'P656', 'Beauty', '717', '5', '5', '1.8'],
#  ['OD1157', 'P657', 'Electronics', '36987', '2', '15', '3.3'],
#  ['OD1158', 'P658', 'Home', '5064', '1', '15', '4.9'],
#  ['OD1159', 'P659', 'Fashion', '2749', '1', '0', '2.2'],
#  ['OD1160', 'P660', 'Fashion', '2708', '4', '20', '1.5'],
#  ['OD1161', 'P661', 'Electronics', '45945', '2', '10', '3.9'],
#  ['OD1162', 'P662', 'Home', '18322', '1', '5', '1.3'],
#  ['OD1163', 'P663', 'Electronics', '24293', '3', '20', '1.7'],
#  ['OD1164', 'P664', 'Home', '1115', '1', '25', '4.2'],
#  ['OD1165', 'P665', 'Beauty', '273', '1', '10', '3.4'],
#  ['OD1166', 'P666', 'Books', '161', '1', '25', '4.3'],
#  ['OD1167', 'P667', 'Grocery', '708', '5', '0', '2.9'],
#  ['OD1168', 'P668', 'Electronics', '40534', '1', '20', '1.2'],
#  ['OD1169', 'P669', 'Electronics', '29689', '4', '0', '3.1'],
#  ['OD1170', 'P670', 'Fashion', '1868', '3', '20', '3.3'],
#  ['OD1171', 'P671', 'Grocery', '584', '5', '5', '4.4'],
#  ['OD1172', 'P672', 'Electronics', '13956', '5', '25', '1.8'],
#  ['OD1173', 'P673', 'Electronics', '35316', '3', '20', '3.4'],
#  ['OD1174', 'P674', 'Electronics', '22449', '1', '0', '4.0'],
#  ['OD1175', 'P675', 'Books', '132', '4', '30', '1.5'],
#  ['OD1176', 'P676', 'Fashion', '2401', '2', '5', '2.9'],
#  ['OD1177', 'P677', 'Grocery', '790', '3', '5', '4.4'],
#  ['OD1178', 'P678', 'Home', '17561', '4', '20', '1.4'],
#  ['OD1179', 'P679', 'Electronics', '38126', '1', '0', '1.5'],
#  ['OD1180', 'P680', 'Home', '19858', '5', '20', '3.6'],
#  ['OD1181', 'P681', 'Electronics', '27198', '3', '30', '1.5'],
#  ['OD1182', 'P682', 'Fashion', '963', '2', '25', '3.4'],
#  ['OD1183', 'P683', 'Fashion', '1558', '3', '10', '4.6'],
#  ['OD1184', 'P684', 'Electronics', '18215', '1', '25', '2.8'],
#  ['OD1185', 'P685', 'Home', '9650', '4', '25', '3.5'],
#  ['OD1186', 'P686', 'Grocery', '582', '1', '20', '4.2'],
#  ['OD1187', 'P687', 'Grocery', '157', '1', '5', '4.1'],
#  ['OD1188', 'P688', 'Grocery', '871', '5', '5', '3.5'],
#  ['OD1189', 'P689', 'Electronics', '6069', '5', '25', '3.5'],
#  ['OD1190', 'P690', 'Electronics', '12515', '3', '10', '3.1'],
#  ['OD1191', 'P691', 'Electronics', '24714', '3', '25', '3.8'],
#  ['OD1192', 'P692', 'Electronics', '45915', '4', '0', '4.6'],
#  ['OD1193', 'P693', 'Electronics', '36534', '3', '20', '4.9'],
#  ['OD1194', 'P694', 'Books', '159', '2', '10', '1.2'],
#  ['OD1195', 'P695', 'Fashion', '1228', '2', '15', '2.4'],
#  ['OD1196', 'P696', 'Electronics', '23561', '5', '25', '1.5'],
#  ['OD1197', 'P697', 'Home', '6476', '4', '5', '4.6'],
#  ['OD1198', 'P698', 'Electronics', '43428', '2', '20', '2.3'],
#  ['OD1199', 'P699', 'Fashion', '2496', '1', '25', '1.3'],
#  ['OD1200', 'P700', 'Electronics', '45662', '5', '0', '2.1'],
#  ['OD1201', 'P701', 'Books', '355', '1', '10', '1.7'],
#  ['OD1202', 'P702', 'Home', '402', '2', '15', '2.5'],
#  ['OD1203', 'P703', 'Fashion', '564', '2', '25', '1.6'],
#  ['OD1204', 'P704', 'Electronics', '5626', '3', '30', '4.4'],
#  ['OD1205', 'P705', 'Electronics', '39138', '4', '20', '4.5'],
#  ['OD1206', 'P706', 'Electronics', '23833', '3', '10', '2.0'],
#  ['OD1207', 'P707', 'Fashion', '1854', '5', '15', '1.1'],
#  ['OD1208', 'P708', 'Home', '18460', '1', '30', '1.4'],
#  ['OD1209', 'P709', 'Electronics', '49777', '4', '0', '4.6'],
#  ['OD1210', 'P710', 'Grocery', '231', '1', '15', '2.4'],
#  ['OD1211', 'P711', 'Electronics', '17116', '5', '5', '1.3'],
#  ['OD1212', 'P712', 'Fashion', '310', '2', '30', '4.0'],
#  ['OD1213', 'P713', 'Beauty', '2845', '3', '5', '2.1'],
#  ['OD1214', 'P714', 'Electronics', '19623', '2', '5', '2.0'],
#  ['OD1215', 'P715', 'Books', '413', '5', '25', '3.4'],
#  ['OD1216', 'P716', 'Electronics', '27785', '5', '25', '2.5'],
#  ['OD1217', 'P717', 'Home', '6867', '4', '25', '1.7'],
#  ['OD1218', 'P718', 'Grocery', '849', '1', '30', '1.2'],
#  ['OD1219', 'P719', 'Electronics', '35858', '5', '15', '5.0'],
#  ['OD1220', 'P720', 'Home', '16489', '2', '15', '4.9'],
#  ['OD1221', 'P721', 'Electronics', '22850', '1', '25', '1.7'],
#  ['OD1222', 'P722', 'Beauty', '996', '1', '5', '3.2'],
#  ['OD1223', 'P723', 'Electronics', '14203', '2', '10', '4.4'],
#  ['OD1224', 'P724', 'Grocery', '664', '2', '25', '3.8'],
#  ['OD1225', 'P725', 'Home', '16708', '4', '0', '3.1'],
#  ['OD1226', 'P726', 'Beauty', '2098', '2', '25', '2.2'],
#  ['OD1227', 'P727', 'Home', '1928', '3', '30', '2.9'],
#  ['OD1228', 'P728', 'Fashion', '2226', '3', '0', '2.5'],
#  ['OD1229', 'P729', 'Fashion', '2239', '2', '20', '1.3'],
#  ['OD1230', 'P730', 'Books', '270', '2', '20', '3.7'],
#  ['OD1231', 'P731', 'Fashion', '1819', '1', '30', '3.7'],
#  ['OD1232', 'P732', 'Electronics', '19716', '1', '10', '2.9'],
#  ['OD1233', 'P733', 'Fashion', '2238', '3', '25', '1.4'],
#  ['OD1234', 'P734', 'Beauty', '1654', '4', '15', '2.6'],
#  ['OD1235', 'P735', 'Electronics', '2408', '3', '0', '1.8'],
#  ['OD1236', 'P736', 'Electronics', '8662', '3', '0', '4.0'],
#  ['OD1237', 'P737', 'Home', '11257', '4', '20', '1.6'],
#  ['OD1238', 'P738', 'Electronics', '42332', '5', '25', '4.2'],
#  ['OD1239', 'P739', 'Grocery', '310', '5', '20', '4.3'],
#  ['OD1240', 'P740', 'Fashion', '277', '2', '25', '2.4'],
#  ['OD1241', 'P741', 'Books', '847', '2', '0', '3.7'],
#  ['OD1242', 'P742', 'Electronics', '10010', '3', '20', '2.2'],
#  ['OD1243', 'P743', 'Fashion', '1246', '1', '0', '2.4'],
#  ['OD1244', 'P744', 'Electronics', '11746', '2', '25', '1.3'],
#  ['OD1245', 'P745', 'Home', '4118', '3', '25', '4.8'],
#  ['OD1246', 'P746', 'Grocery', '410', '3', '5', '1.6'],
#  ['OD1247', 'P747', 'Electronics', '15874', '5', '0', '3.1'],
#  ['OD1248', 'P748', 'Fashion', '1454', '3', '15', '5.0'],
#  ['OD1249', 'P749', 'Fashion', '1320', '5', '20', '4.1'],
#  ['OD1250', 'P750', 'Home', '2436', '4', '25', '3.9'],
#  ['OD1251', 'P751', 'Home', '4712', '3', '5', '2.4'],
#  ['OD1252', 'P752', 'Electronics', '24210', '4', '20', '1.5'],
#  ['OD1253', 'P753', 'Fashion', '2262', '5', '20', '2.9'],
#  ['OD1254', 'P754', 'Electronics', '19255', '4', '20', '3.9'],
#  ['OD1255', 'P755', 'Books', '193', '3', '10', '3.3'],
#  ['OD1256', 'P756', 'Grocery', '813', '3', '10', '2.4'],
#  ['OD1257', 'P757', 'Books', '109', '2', '25', '1.9'],
#  ['OD1258', 'P758', 'Home', '914', '2', '25', '3.5'],
#  ['OD1259', 'P759', 'Home', '10557', '5', '25', '1.4'],
#  ['OD1260', 'P760', 'Home', '15428', '4', '10', '4.7'],
#  ['OD1261', 'P761', 'Electronics', '37719', '4', '20', '4.7'],
#  ['OD1262', 'P762', 'Electronics', '39227', '2', '0', '3.3'],
#  ['OD1263', 'P763', 'Electronics', '44909', '1', '25', '1.3'],
#  ['OD1264', 'P764', 'Electronics', '44827', '1', '25', '4.6'],
#  ['OD1265', 'P765', 'Fashion', '1992', '5', '20', '1.7'],
#  ['OD1266', 'P766', 'Electronics', '48023', '1', '0', '4.5'],
#  ['OD1267', 'P767', 'Grocery', '586', '3', '30', '2.6'],
#  ['OD1268', 'P768', 'Fashion', '1532', '1', '5', '4.2'],
#  ['OD1269', 'P769', 'Fashion', '316', '2', '0', '1.5'],
#  ['OD1270', 'P770', 'Grocery', '263', '1', '5', '4.7'],
#  ['OD1271', 'P771', 'Grocery', '405', '2', '10', '4.0'],
#  ['OD1272', 'P772', 'Fashion', '2887', '3', '10', '2.8'],
#  ['OD1273', 'P773', 'Fashion', '1402', '1', '30', '1.7'],
#  ['OD1274', 'P774', 'Grocery', '520', '1', '0', '4.1'],
#  ['OD1275', 'P775', 'Fashion', '1202', '2', '15', '1.9'],
#  ['OD1276', 'P776', 'Fashion', '1166', '1', '15', '2.8'],
#  ['OD1277', 'P777', 'Electronics', '37511', '4', '30', '5.0'],
#  ['OD1278', 'P778', 'Books', '659', '1', '20', '2.6'],
#  ['OD1279', 'P779', 'Electronics', '2982', '3', '10', '2.4'],
#  ['OD1280', 'P780', 'Fashion', '2917', '5', '0', '1.1'],
#  ['OD1281', 'P781', 'Beauty', '335', '3', '5', '2.2'],
#  ['OD1282', 'P782', 'Electronics', '38758', '2', '5', '3.1'],
#  ['OD1283', 'P783', 'Grocery', '132', '2', '25', '3.2'],
#  ['OD1284', 'P784', 'Beauty', '880', '4', '0', '2.3'],
#  ['OD1285', 'P785', 'Electronics', '12842', '3', '5', '2.1'],
#  ['OD1286', 'P786', 'Fashion', '2101', '2', '15', '4.2'],
#  ['OD1287', 'P787', 'Fashion', '254', '4', '5', '4.5'],
#  ['OD1288', 'P788', 'Electronics', '44539', '1', '0', '1.9'],
#  ['OD1289', 'P789', 'Electronics', '47563', '3', '30', '1.1'],
#  ['OD1290', 'P790', 'Books', '152', '1', '30', '3.3'],
#  ['OD1291', 'P791', 'Fashion', '1487', '2', '10', '2.0'],
#  ['OD1292', 'P792', 'Electronics', '32321', '3', '15', '4.8'],
#  ['OD1293', 'P793', 'Fashion', '381', '5', '25', '2.2'],
#  ['OD1294', 'P794', 'Electronics', '17827', '2', '30', '3.5'],
#  ['OD1295', 'P795', 'Electronics', '16532', '5', '10', '1.5'],
#  ['OD1296', 'P796', 'Electronics', '42374', '4', '20', '2.7'],
#  ['OD1297', 'P797', 'Books', '612', '1', '30', '3.5'],
#  ['OD1298', 'P798', 'Fashion', '945', '2', '10', '3.4'],
#  ['OD1299', 'P799', 'Home', '18039', '5', '20', '2.6'],
#  ['OD1300', 'P800', 'Fashion', '1957', '1', '5', '4.4'],
#  ['OD1301', 'P801', 'Electronics', '44361', '4', '0', '4.5'],
#  ['OD1302', 'P802', 'Grocery', '651', '3', '25', '2.9'],
#  ['OD1303', 'P803', 'Electronics', '38099', '1', '5', '1.1'],
#  ['OD1304', 'P804', 'Fashion', '2773', '1', '5', '3.5'],
#  ['OD1305', 'P805', 'Electronics', '24252', '3', '25', '4.9'],
#  ['OD1306', 'P806', 'Home', '8733', '5', '20', '3.8'],
#  ['OD1307', 'P807', 'Home', '9096', '3', '25', '4.7'],
#  ['OD1308', 'P808', 'Fashion', '2289', '4', '0', '2.1'],
#  ['OD1309', 'P809', 'Fashion', '1900', '1', '25', '4.3'],
#  ['OD1310', 'P810', 'Fashion', '1822', '5', '5', '1.6'],
#  ['OD1311', 'P811', 'Fashion', '2274', '1', '30', '4.5'],
#  ['OD1312', 'P812', 'Grocery', '187', '2', '15', '3.5'],
#  ['OD1313', 'P813', 'Home', '15256', '2', '20', '4.4'],
#  ['OD1314', 'P814', 'Fashion', '901', '2', '25', '1.2'],
#  ['OD1315', 'P815', 'Home', '3167', '3', '0', '1.3'],
#  ['OD1316', 'P816', 'Home', '11655', '3', '5', '1.3'],
#  ['OD1317', 'P817', 'Fashion', '1519', '3', '15', '3.9'],
#  ['OD1318', 'P818', 'Home', '11146', '3', '25', '2.9'],
#  ['OD1319', 'P819', 'Home', '2811', '5', '0', '2.1'],
#  ['OD1320', 'P820', 'Fashion', '950', '4', '10', '3.4'],
#  ['OD1321', 'P821', 'Books', '589', '1', '25', '4.8'],
#  ['OD1322', 'P822', 'Electronics', '39390', '2', '0', '4.1'],
#  ['OD1323', 'P823', 'Electronics', '2024', '1', '0', '2.4'],
#  ['OD1324', 'P824', 'Grocery', '660', '1', '20', '3.8'],
#  ['OD1325', 'P825', 'Fashion', '2289', '1', '30', '1.3'],
#  ['OD1326', 'P826', 'Electronics', '28645', '5', '15', '3.8'],
#  ['OD1327', 'P827', 'Electronics', '20433', '2', '15', '2.4'],
#  ['OD1328', 'P828', 'Fashion', '1240', '2', '0', '2.8'],
#  ['OD1329', 'P829', 'Fashion', '211', '3', '30', '4.2'],
#  ['OD1330', 'P830', 'Beauty', '1800', '5', '25', '3.5'],
#  ['OD1331', 'P831', 'Grocery', '219', '1', '5', '3.0'],
#  ['OD1332', 'P832', 'Electronics', '12418', '3', '5', '1.2'],
#  ['OD1333', 'P833', 'Grocery', '557', '2', '30', '5.0'],
#  ['OD1334', 'P834', 'Electronics', '22797', '5', '25', '4.7'],
#  ['OD1335', 'P835', 'Home', '12145', '5', '30', '2.2'],
#  ['OD1336', 'P836', 'Electronics', '15523', '2', '10', '4.8'],
#  ['OD1337', 'P837', 'Electronics', '7237', '4', '30', '2.8'],
#  ['OD1338', 'P838', 'Grocery', '462', '2', '30', '1.1'],
#  ['OD1339', 'P839', 'Home', '9474', '3', '15', '1.5'],
#  ['OD1340', 'P840', 'Grocery', '117', '3', '20', '3.1'],
#  ['OD1341', 'P841', 'Home', '12751', '1', '15', '4.2'],
#  ['OD1342', 'P842', 'Electronics', '8064', '2', '0', '4.5'],
#  ['OD1343', 'P843', 'Electronics', '14237', '4', '25', '2.7'],
#  ['OD1344', 'P844', 'Electronics', '1045', '3', '30', '1.7'],
#  ['OD1345', 'P845', 'Home', '15875', '3', '10', '5.0'],
#  ['OD1346', 'P846', 'Fashion', '228', '1', '20', '1.2'],
#  ['OD1347', 'P847', 'Electronics', '13484', '4', '30', '2.6'],
#  ['OD1348', 'P848', 'Fashion', '1120', '4', '20', '3.9'],
#  ['OD1349', 'P849', 'Books', '787', '3', '20', '2.4'],
#  ['OD1350', 'P850', 'Home', '2133', '4', '5', '1.9'],
#  ['OD1351', 'P851', 'Electronics', '41100', '1', '20', '5.0'],
#  ['OD1352', 'P852', 'Fashion', '2832', '1', '0', '3.7'],
#  ['OD1353', 'P853', 'Fashion', '2434', '2', '20', '4.1'],
#  ['OD1354', 'P854', 'Fashion', '1138', '4', '25', '4.9'],
#  ['OD1355', 'P855', 'Electronics', '41470', '5', '5', '1.7'],
#  ['OD1356', 'P856', 'Books', '662', '4', '10', '2.6'],
#  ['OD1357', 'P857', 'Home', '16320', '5', '10', '3.1'],
#  ['OD1358', 'P858', 'Beauty', '275', '1', '5', '1.1'],
#  ['OD1359', 'P859', 'Fashion', '2753', '3', '25', '4.2'],
#  ['OD1360', 'P860', 'Books', '152', '1', '0', '4.7'],
#  ['OD1361', 'P861', 'Grocery', '909', '1', '20', '2.0'],
#  ['OD1362', 'P862', 'Grocery', '438', '2', '5', '3.8'],
#  ['OD1363', 'P863', 'Home', '14651', '3', '10', '1.9'],
#  ['OD1364', 'P864', 'Electronics', '7787', '5', '30', '1.1'],
#  ['OD1365', 'P865', 'Electronics', '37943', '5', '5', '2.8'],
#  ['OD1366', 'P866', 'Electronics', '46507', '3', '10', '1.5'],
#  ['OD1367', 'P867', 'Electronics', '18102', '1', '5', '4.4'],
#  ['OD1368', 'P868', 'Beauty', '570', '1', '20', '3.9'],
#  ['OD1369', 'P869', 'Books', '324', '4', '30', '1.0'],
#  ['OD1370', 'P870', 'Grocery', '270', '5', '5', '3.1'],
#  ['OD1371', 'P871', 'Fashion', '236', '4', '20', '4.6'],
#  ['OD1372', 'P872', 'Electronics', '21952', '1', '5', '3.0'],
#  ['OD1373', 'P873', 'Home', '14659', '5', '10', '4.3'],
#  ['OD1374', 'P874', 'Grocery', '587', '2', '10', '4.5'],
#  ['OD1375', 'P875', 'Books', '387', '3', '15', '4.4'],
#  ['OD1376', 'P876', 'Grocery', '590', '1', '20', '4.3'],
#  ['OD1377', 'P877', 'Fashion', '1916', '2', '15', '3.5'],
#  ['OD1378', 'P878', 'Home', '2569', '4', '30', '4.5'],
#  ['OD1379', 'P879', 'Fashion', '756', '2', '0', '1.1'],
#  ['OD1380', 'P880', 'Home', '14970', '2', '5', '4.3'],
#  ['OD1381', 'P881', 'Grocery', '456', '2', '15', '3.2'],
#  ['OD1382', 'P882', 'Home', '394', '2', '20', '3.5'],
#  ['OD1383', 'P883', 'Grocery', '132', '1', '0', '1.5'],
#  ['OD1384', 'P884', 'Home', '7109', '4', '20', '4.1'],
#  ['OD1385', 'P885', 'Beauty', '1399', '3', '25', '1.1'],
#  ['OD1386', 'P886', 'Home', '9539', '2', '30', '2.6'],
#  ['OD1387', 'P887', 'Electronics', '35650', '5', '20', '4.2'],
#  ['OD1388', 'P888', 'Grocery', '935', '4', '5', '4.8'],
#  ['OD1389', 'P889', 'Fashion', '2439', '1', '15', '1.3'],
#  ['OD1390', 'P890', 'Electronics', '8573', '1', '25', '3.5'],
#  ['OD1391', 'P891', 'Electronics', '49646', '2', '5', '5.0'],
#  ['OD1392', 'P892', 'Books', '785', '5', '15', '4.0'],
#  ['OD1393', 'P893', 'Grocery', '246', '4', '20', '2.5'],
#  ['OD1394', 'P894', 'Fashion', '228', '3', '0', '2.3'],
#  ['OD1395', 'P895', 'Fashion', '2326', '3', '10', '3.7'],
#  ['OD1396', 'P896', 'Fashion', '1653', '2', '20', '4.8'],
#  ['OD1397', 'P897', 'Beauty', '2494', '1', '30', '3.1'],
#  ['OD1398', 'P898', 'Beauty', '2894', '5', '10', '1.9'],
#  ['OD1399', 'P899', 'Electronics', '47266', '4', '25', '1.5'],
#  ['OD1400', 'P900', 'Electronics', '44913', '4', '15', '3.9'],
#  ['OD1401', 'P901', 'Fashion', '2550', '5', '10', '4.9'],
#  ['OD1402', 'P902', 'Electronics', '34950', '1', '20', '4.9'],
#  ['OD1403', 'P903', 'Electronics', '7924', '2', '15', '3.9'],
#  ['OD1404', 'P904', 'Fashion', '2180', '3', '0', '3.6'],
#  ['OD1405', 'P905', 'Electronics', '49151', '2', '30', '2.9'],
#  ['OD1406', 'P906', 'Grocery', '558', '4', '25', '1.8'],
#  ['OD1407', 'P907', 'Home', '3776', '5', '30', '2.8'],
#  ['OD1408', 'P908', 'Fashion', '2235', '3', '20', '1.5'],
#  ['OD1409', 'P909', 'Fashion', '892', '4', '5', '3.5'],
#  ['OD1410', 'P910', 'Grocery', '577', '1', '25', '1.5'],
#  ['OD1411', 'P911', 'Books', '371', '4', '15', '2.7'],
#  ['OD1412', 'P912', 'Electronics', '39065', '1', '15', '1.3'],
#  ['OD1413', 'P913', 'Beauty', '1063', '5', '20', '3.4'],
#  ['OD1414', 'P914', 'Electronics', '17467', '3', '20', '1.6'],
#  ['OD1415', 'P915', 'Electronics', '27089', '2', '25', '4.9'],
#  ['OD1416', 'P916', 'Books', '264', '3', '20', '4.0'],
#  ['OD1417', 'P917', 'Electronics', '21081', '1', '10', '2.9'],
#  ['OD1418', 'P918', 'Electronics', '46667', '1', '0', '1.4'],
#  ['OD1419', 'P919', 'Books', '144', '4', '15', '2.4'],
#  ['OD1420', 'P920', 'Electronics', '9627', '2', '15', '1.3'],
#  ['OD1421', 'P921', 'Fashion', '2472', '1', '0', '2.4'],
#  ['OD1422', 'P922', 'Electronics', '23616', '4', '5', '2.6'],
#  ['OD1423', 'P923', 'Fashion', '2441', '2', '25', '3.8'],
#  ['OD1424', 'P924', 'Grocery', '162', '2', '5', '1.7'],
#  ['OD1425', 'P925', 'Home', '18379', '3', '20', '3.8'],
#  ['OD1426', 'P926', 'Fashion', '2125', '1', '25', '3.5'],
#  ['OD1427', 'P927', 'Electronics', '26515', '1', '5', '4.7'],
#  ['OD1428', 'P928', 'Books', '938', '2', '15', '4.2'],
#  ['OD1429', 'P929', 'Electronics', '14129', '3', '30', '1.3'],
#  ['OD1430', 'P930', 'Grocery', '103', '4', '25', '4.3'],
#  ['OD1431', 'P931', 'Home', '8701', '3', '30', '3.1'],
#  ['OD1432', 'P932', 'Fashion', '1073', '3', '5', '1.2'],
#  ['OD1433', 'P933', 'Electronics', '10826', '4', '20', '2.9'],
#  ['OD1434', 'P934', 'Books', '341', '2', '10', '4.9'],
#  ['OD1435', 'P935', 'Electronics', '5280', '5', '30', '2.7'],
#  ['OD1436', 'P936', 'Fashion', '2535', '3', '15', '3.2'],
#  ['OD1437', 'P937', 'Electronics', '40325', '3', '25', '2.3'],
#  ['OD1438', 'P938', 'Fashion', '511', '1', '10', '3.6'],
#  ['OD1439', 'P939', 'Books', '812', '3', '10', '1.9'],
#  ['OD1440', 'P940', 'Electronics', '16809', '1', '30', '2.9'],
#  ['OD1441', 'P941', 'Grocery', '881', '5', '30', '2.7'],
#  ['OD1442', 'P942', 'Fashion', '2271', '4', '20', '2.4'],
#  ['OD1443', 'P943', 'Fashion', '1587', '4', '15', '1.2'],
#  ['OD1444', 'P944', 'Home', '18196', '3', '0', '2.8'],
#  ['OD1445', 'P945', 'Home', '12103', '2', '30', '4.6'],
#  ['OD1446', 'P946', 'Grocery', '793', '2', '10', '3.4'],
#  ['OD1447', 'P947', 'Home', '9561', '5', '15', '2.5'],
#  ['OD1448', 'P948', 'Fashion', '729', '5', '30', '1.9'],
#  ['OD1449', 'P949', 'Grocery', '813', '4', '25', '1.7'],
#  ['OD1450', 'P950', 'Electronics', '42399', '2', '30', '2.7'],
#  ['OD1451', 'P951', 'Fashion', '752', '4', '20', '2.8'],
#  ['OD1452', 'P952', 'Books', '602', '1', '15', '3.4'],
#  ['OD1453', 'P953', 'Fashion', '1037', '1', '10', '2.2'],
#  ['OD1454', 'P954', 'Grocery', '47', '2', '10', '3.6'],
#  ['OD1455', 'P955', 'Electronics', '43506', '1', '15', '1.5'],
#  ['OD1456', 'P956', 'Electronics', '13088', '3', '5', '1.3'],
#  ['OD1457', 'P957', 'Electronics', '17153', '2', '20', '2.3'],
#  ['OD1458', 'P958', 'Grocery', '881', '1', '0', '2.8'],
#  ['OD1459', 'P959', 'Grocery', '795', '3', '15', '3.8'],
#  ['OD1460', 'P960', 'Fashion', '775', '4', '15', '1.1'],
#  ['OD1461', 'P961', 'Home', '19218', '5', '15', '2.9'],
#  ['OD1462', 'P962', 'Electronics', '36836', '4', '15', '4.5'],
#  ['OD1463', 'P963', 'Home', '18409', '4', '10', '1.4'],
#  ['OD1464', 'P964', 'Electronics', '20837', '2', '0', '3.1'],
#  ['OD1465', 'P965', 'Electronics', '26119', '2', '20', '3.6'],
#  ['OD1466', 'P966', 'Fashion', '1258', '5', '20', '1.4'],
#  ['OD1467', 'P967', 'Electronics', '30356', '1', '10', '1.2'],
#  ['OD1468', 'P968', 'Electronics', '41735', '5', '5', '4.9'],
#  ['OD1469', 'P969', 'Grocery', '830', '2', '0', '3.6'],
#  ['OD1470', 'P970', 'Fashion', '1408', '3', '5', '2.4'],
#  ['OD1471', 'P971', 'Fashion', '1517', '4', '30', '1.1'],
#  ['OD1472', 'P972', 'Home', '12695', '2', '5', '3.9'],
#  ['OD1473', 'P973', 'Fashion', '2233', '5', '0', '3.9'],
#  ['OD1474', 'P974', 'Fashion', '2916', '5', '30', '1.7'],
#  ['OD1475', 'P975', 'Fashion', '2558', '2', '10', '3.7'],
#  ['OD1476', 'P976', 'Books', '212', '2', '0', '4.3'],
#  ['OD1477', 'P977', 'Grocery', '322', '1', '15', '1.5'],
#  ['OD1478', 'P978', 'Electronics', '37708', '4', '0', '3.4'],
#  ['OD1479', 'P979', 'Electronics', '14098', '5', '20', '3.3'],
#  ['OD1480', 'P980', 'Fashion', '1209', '1', '0', '2.6'],
#  ['OD1481', 'P981', 'Fashion', '887', '5', '0', '1.4'],
#  ['OD1482', 'P982', 'Electronics', '20114', '1', '10', '4.5'],
#  ['OD1483', 'P983', 'Grocery', '400', '4', '25', '2.8'],
#  ['OD1484', 'P984', 'Grocery', '501', '2', '20', '4.2'],
#  ['OD1485', 'P985', 'Electronics', '25926', '5', '10', '2.5'],
#  ['OD1486', 'P986', 'Fashion', '1021', '1', '20', '2.3'],
#  ['OD1487', 'P987', 'Fashion', '910', '5', '10', '2.6'],
#  ['OD1488', 'P988', 'Fashion', '1696', '1', '0', '3.2'],
#  ['OD1489', 'P989', 'Electronics', '31510', '4', '25', '1.3'],
#  ['OD1490', 'P990', 'Electronics', '40278', '2', '5', '2.9'],
#  ['OD1491', 'P991', 'Home', '9318', '5', '5', '4.8'],
#  ['OD1492', 'P992', 'Electronics', '43961', '4', '20', '4.3'],
#  ['OD1493', 'P993', 'Fashion', '864', '4', '20', '2.6'],
#  ['OD1494', 'P994', 'Fashion', '1963', '3', '30', '4.3'],
#  ['OD1495', 'P995', 'Fashion', '2745', '4', '10', '3.1'],
#  ['OD1496', 'P996', 'Grocery', '40', '3', '30', '4.6'],
#  ['OD1497', 'P997', 'Books', '215', '4', '30', '2.0'],
#  ['OD1498', 'P998', 'Fashion', '914', '3', '30', '1.8'],
#  ['OD1499', 'P999', 'Electronics', '49792', '3', '5', '1.7'],
#  ['OD1500', 'P1000', 'Fashion', '1163', '5', '15', '3.7'],
#  ['OD1501', 'P1001', 'Fashion', '1892', '4', '10', '3.3'],
#  ['OD1502', 'P1002', 'Home', '16589', '4', '25', '3.9'],
#  ['OD1503', 'P1003', 'Electronics', '45476', '5', '15', '4.3'],
#  ['OD1504', 'P1004', 'Beauty', '399', '3', '30', '3.7'],
#  ['OD1505', 'P1005', 'Home', '16045', '5', '30', '3.8'],
#  ['OD1506', 'P1006', 'Fashion', '2559', '1', '5', '1.7'],
#  ['OD1507', 'P1007', 'Books', '134', '4', '15', '1.3'],
#  ['OD1508', 'P1008', 'Home', '9700', '4', '20', '3.5'],
#  ['OD1509', 'P1009', 'Grocery', '910', '5', '30', '3.6'],
#  ['OD1510', 'P1010', 'Electronics', '34568', '4', '0', '4.2'],
#  ['OD1511', 'P1011', 'Beauty', '1856', '2', '5', '2.4'],
#  ['OD1512', 'P1012', 'Fashion', '2929', '1', '5', '2.0'],
#  ['OD1513', 'P1013', 'Grocery', '599', '2', '10', '4.4'],
#  ['OD1514', 'P1014', 'Home', '3373', '1', '5', '4.1'],
#  ['OD1515', 'P1015', 'Fashion', '1662', '2', '20', '1.7'],
#  ['OD1516', 'P1016', 'Electronics', '18133', '1', '30', '3.1'],
#  ['OD1517', 'P1017', 'Electronics', '42121', '5', '30', '1.9'],
#  ['OD1518', 'P1018', 'Home', '7722', '3', '5', '2.0'],
#  ['OD1519', 'P1019', 'Books', '175', '5', '0', '3.0'],
#  ['OD1520', 'P1020', 'Electronics', '34037', '3', '30', '3.8'],
#  ['OD1521', 'P1021', 'Books', '933', '2', '25', '2.8'],
#  ['OD1522', 'P1022', 'Electronics', '32996', '3', '30', '2.4'],
#  ['OD1523', 'P1023', 'Electronics', '38967', '2', '25', '3.3'],
#  ['OD1524', 'P1024', 'Grocery', '186', '5', '25', '2.1'],
#  ['OD1525', 'P1025', 'Electronics', '47320', '1', '15', '1.8'],
#  ['OD1526', 'P1026', 'Fashion', '2895', '1', '10', '2.4'],
#  ['OD1527', 'P1027', 'Fashion', '907', '5', '0', '4.3'],
#  ['OD1528', 'P1028', 'Fashion', '1155', '5', '15', '1.9'],
#  ['OD1529', 'P1029', 'Electronics', '14984', '2', '10', '3.1'],
#  ['OD1530', 'P1030', 'Grocery', '400', '2', '10', '1.8'],
#  ['OD1531', 'P1031', 'Books', '228', '4', '5', '2.5'],
#  ['OD1532', 'P1032', 'Fashion', '2601', '4', '25', '3.2'],
#  ['OD1533', 'P1033', 'Electronics', '48056', '5', '20', '3.8'],
#  ['OD1534', 'P1034', 'Electronics', '26092', '2', '25', '2.7'],
#  ['OD1535', 'P1035', 'Fashion', '2302', '4', '0', '2.2'],
#  ['OD1536', 'P1036', 'Electronics', '20603', '4', '10', '4.7'],
#  ['OD1537', 'P1037', 'Home', '336', '4', '10', '1.6'],
#  ['OD1538', 'P1038', 'Books', '615', '4', '15', '2.0'],
#  ['OD1539', 'P1039', 'Grocery', '305', '5', '15', '3.5'],
#  ['OD1540', 'P1040', 'Books', '554', '1', '20', '4.3'],
#  ['OD1541', 'P1041', 'Fashion', '1723', '2', '20', '1.1'],
#  ['OD1542', 'P1042', 'Electronics', '6282', '2', '20', '2.4'],
#  ['OD1543', 'P1043', 'Grocery', '360', '2', '10', '2.0'],
#  ['OD1544', 'P1044', 'Books', '547', '3', '10', '2.6'],
#  ['OD1545', 'P1045', 'Electronics', '18573', '4', '5', '3.1'],
#  ['OD1546', 'P1046', 'Home', '17926', '3', '30', '5.0'],
#  ['OD1547', 'P1047', 'Grocery', '120', '4', '5', '3.0'],
#  ['OD1548', 'P1048', 'Fashion', '760', '2', '25', '4.3'],
#  ['OD1549', 'P1049', 'Electronics', '35094', '2', '25', '3.9'],
#  ['OD1550', 'P1050', 'Fashion', '1147', '1', '30', '2.6'],
#  ['OD1551', 'P1051', 'Electronics', '7221', '3', '5', '1.9'],
#  ['OD1552', 'P1052', 'Fashion', '2011', '2', '5', '4.3'],
#  ['OD1553', 'P1053', 'Home', '9084', '5', '25', '2.3'],
#  ['OD1554', 'P1054', 'Grocery', '114', '1', '25', '4.6'],
#  ['OD1555', 'P1055', 'Fashion', '437', '5', '15', '3.0'],
#  ['OD1556', 'P1056', 'Fashion', '2160', '1', '20', '2.5'],
#  ['OD1557', 'P1057', 'Grocery', '411', '5', '5', '3.0'],
#  ['OD1558', 'P1058', 'Books', '177', '4', '20', '3.2'],
#  ['OD1559', 'P1059', 'Electronics', '8467', '4', '20', '4.7'],
#  ['OD1560', 'P1060', 'Grocery', '551', '2', '20', '1.4'],
#  ['OD1561', 'P1061', 'Home', '12777', '5', '10', '3.5'],
#  ['OD1562', 'P1062', 'Fashion', '1283', '3', '30', '1.2'],
#  ['OD1563', 'P1063', 'Electronics', '43413', '2', '0', '1.2'],
#  ['OD1564', 'P1064', 'Home', '3950', '2', '20', '3.5'],
#  ['OD1565', 'P1065', 'Books', '561', '1', '30', '2.0'],
#  ['OD1566', 'P1066', 'Fashion', '1322', '5', '0', '4.1'],
#  ['OD1567', 'P1067', 'Grocery', '513', '3', '30', '3.8'],
#  ['OD1568', 'P1068', 'Electronics', '23791', '1', '15', '3.5'],
#  ['OD1569', 'P1069', 'Electronics', '23812', '5', '30', '1.9'],
#  ['OD1570', 'P1070', 'Home', '3392', '4', '15', '3.1'],
#  ['OD1571', 'P1071', 'Fashion', '1708', '4', '30', '2.8'],
#  ['OD1572', 'P1072', 'Books', '581', '3', '15', '2.9'],
#  ['OD1573', 'P1073', 'Fashion', '2702', '5', '20', '4.1'],
#  ['OD1574', 'P1074', 'Grocery', '529', '2', '25', '2.9'],
#  ['OD1575', 'P1075', 'Home', '18777', '5', '5', '3.7'],
#  ['OD1576', 'P1076', 'Home', '5642', '5', '0', '2.3'],
#  ['OD1577', 'P1077', 'Fashion', '2209', '2', '20', '4.9'],
#  ['OD1578', 'P1078', 'Home', '2485', '5', '20', '1.2'],
#  ['OD1579', 'P1079', 'Beauty', '514', '3', '0', '3.2'],
#  ['OD1580', 'P1080', 'Fashion', '902', '5', '15', '2.1'],
#  ['OD1581', 'P1081', 'Electronics', '29800', '2', '25', '1.6'],
#  ['OD1582', 'P1082', 'Grocery', '583', '4', '5', '2.9'],
#  ['OD1583', 'P1083', 'Fashion', '1968', '5', '15', '4.4'],
#  ['OD1584', 'P1084', 'Fashion', '2801', '5', '5', '4.6'],
#  ['OD1585', 'P1085', 'Home', '116', '1', '0', '3.8'],
#  ['OD1586', 'P1086', 'Electronics', '4131', '5', '0', '4.4'],
#  ['OD1587', 'P1087', 'Home', '18763', '5', '15', '3.5'],
#  ['OD1588', 'P1088', 'Grocery', '821', '3', '25', '3.5'],
#  ['OD1589', 'P1089', 'Books', '177', '1', '15', '2.8'],
#  ['OD1590', 'P1090', 'Electronics', '31686', '5', '15', '3.0'],
#  ['OD1591', 'P1091', 'Electronics', '27224', '5', '0', '4.0'],
#  ['OD1592', 'P1092', 'Grocery', '404', '5', '10', '1.3'],
#  ['OD1593', 'P1093', 'Beauty', '2761', '1', '20', '3.0'],
#  ['OD1594', 'P1094', 'Books', '330', '2', '30', '2.2'],
#  ['OD1595', 'P1095', 'Books', '749', '4', '30', '4.8'],
#  ['OD1596', 'P1096', 'Fashion', '2746', '4', '10', '1.7'],
#  ['OD1597', 'P1097', 'Electronics', '30456', '5', '25', '4.3'],
#  ['OD1598', 'P1098', 'Electronics', '11259', '2', '25', '1.3'],
#  ['OD1599', 'P1099', 'Fashion', '2615', '4', '0', '2.2'],
#  ['OD1600', 'P1100', 'Electronics', '35644', '2', '30', '1.8'],
#  ['OD1601', 'P1101', 'Electronics', '12324', '4', '25', '2.0'],
#  ['OD1602', 'P1102', 'Fashion', '1840', '1', '0', '3.1'],
#  ['OD1603', 'P1103', 'Electronics', '21169', '2', '5', '4.2'],
#  ['OD1604', 'P1104', 'Home', '6078', '2', '25', '2.9'],
#  ['OD1605', 'P1105', 'Electronics', '39571', '4', '5', '1.5'],
#  ['OD1606', 'P1106', 'Fashion', '982', '1', '5', '1.9'],
#  ['OD1607', 'P1107', 'Grocery', '684', '3', '25', '2.8'],
#  ['OD1608', 'P1108', 'Beauty', '2887', '4', '25', '4.7'],
#  ['OD1609', 'P1109', 'Beauty', '735', '1', '20', '2.1'],
#  ['OD1610', 'P1110', 'Electronics', '49258', '1', '15', '4.7'],
#  ['OD1611', 'P1111', 'Electronics', '35464', '5', '25', '2.8'],
#  ['OD1612', 'P1112', 'Books', '400', '4', '10', '2.3'],
#  ['OD1613', 'P1113', 'Home', '10873', '4', '20', '3.9'],
#  ['OD1614', 'P1114', 'Fashion', '969', '5', '20', '3.9'],
#  ['OD1615', 'P1115', 'Fashion', '482', '2', '30', '3.0'],
#  ['OD1616', 'P1116', 'Electronics', '46986', '4', '20', '2.7'],
#  ['OD1617', 'P1117', 'Home', '1824', '1', '10', '2.2'],
#  ['OD1618', 'P1118', 'Books', '117', '5', '25', '4.5'],
#  ['OD1619', 'P1119', 'Books', '465', '1', '20', '1.6'],
#  ['OD1620', 'P1120', 'Electronics', '41821', '2', '0', '4.0'],
#  ['OD1621', 'P1121', 'Books', '613', '1', '15', '1.4'],
#  ['OD1622', 'P1122', 'Grocery', '243', '2', '5', '1.8'],
#  ['OD1623', 'P1123', 'Home', '3181', '5', '25', '3.5'],
#  ['OD1624', 'P1124', 'Electronics', '25998', '2', '0', '2.5'],
#  ['OD1625', 'P1125', 'Fashion', '1616', '4', '15', '1.0'],
#  ['OD1626', 'P1126', 'Fashion', '2849', '2', '25', '4.3'],
#  ['OD1627', 'P1127', 'Electronics', '14444', '2', '20', '2.5'],
#  ['OD1628', 'P1128', 'Electronics', '37251', '3', '30', '2.2'],
#  ['OD1629', 'P1129', 'Books', '922', '3', '20', '1.5'],
#  ['OD1630', 'P1130', 'Books', '721', '5', '15', '3.9'],
#  ['OD1631', 'P1131', 'Electronics', '48139', '3', '5', '2.6'],
#  ['OD1632', 'P1132', 'Fashion', '1692', '5', '5', '3.5'],
#  ['OD1633', 'P1133', 'Fashion', '1995', '4', '0', '2.6'],
#  ['OD1634', 'P1134', 'Books', '371', '4', '20', '3.6'],
#  ['OD1635', 'P1135', 'Home', '16187', '5', '5', '3.2'],
#  ['OD1636', 'P1136', 'Grocery', '919', '2', '25', '4.2'],
#  ['OD1637', 'P1137', 'Home', '11254', '1', '30', '1.3'],
#  ['OD1638', 'P1138', 'Fashion', '605', '5', '15', '4.1'],
#  ['OD1639', 'P1139', 'Fashion', '1197', '5', '30', '4.3'],
#  ['OD1640', 'P1140', 'Home', '10358', '5', '15', '1.5'],
#  ['OD1641', 'P1141', 'Books', '211', '1', '5', '2.5'],
#  ['OD1642', 'P1142', 'Grocery', '132', '3', '15', '3.9'],
#  ['OD1643', 'P1143', 'Fashion', '1170', '1', '15', '2.2'],
#  ['OD1644', 'P1144', 'Fashion', '360', '1', '25', '3.5'],
#  ['OD1645', 'P1145', 'Electronics', '30947', '3', '30', '2.6'],
#  ['OD1646', 'P1146', 'Electronics', '19009', '4', '10', '4.0'],
#  ['OD1647', 'P1147', 'Electronics', '46157', '5', '0', '3.3'],
#  ['OD1648', 'P1148', 'Fashion', '337', '2', '10', '1.1'],
#  ['OD1649', 'P1149', 'Electronics', '28772', '5', '25', '3.1'],
#  ['OD1650', 'P1150', 'Grocery', '896', '3', '20', '1.2'],
#  ['OD1651', 'P1151', 'Electronics', '25622', '2', '10', '2.5'],
#  ['OD1652', 'P1152', 'Electronics', '8499', '5', '15', '4.2'],
#  ['OD1653', 'P1153', 'Home', '15533', '5', '15', '1.5'],
#  ['OD1654', 'P1154', 'Fashion', '837', '2', '10', '2.7'],
#  ['OD1655', 'P1155', 'Electronics', '3884', '4', '25', '1.2'],
#  ['OD1656', 'P1156', 'Home', '17169', '4', '15', '1.5'],
#  ['OD1657', 'P1157', 'Home', '7810', '4', '0', '4.8'],
#  ['OD1658', 'P1158', 'Grocery', '945', '4', '5', '2.1'],
#  ['OD1659', 'P1159', 'Electronics', '9935', '3', '30', '4.6'],
#  ['OD1660', 'P1160', 'Grocery', '651', '2', '25', '2.7'],
#  ['OD1661', 'P1161', 'Electronics', '8396', '5', '25', '1.3'],
#  ['OD1662', 'P1162', 'Fashion', '2036', '4', '10', '1.3'],
#  ['OD1663', 'P1163', 'Electronics', '19181', '3', '0', '2.4'],
#  ['OD1664', 'P1164', 'Books', '788', '1', '10', '2.4'],
#  ['OD1665', 'P1165', 'Home', '14389', '3', '15', '1.5'],
#  ['OD1666', 'P1166', 'Electronics', '42403', '5', '5', '4.3'],
#  ['OD1667', 'P1167', 'Home', '4059', '1', '20', '4.9'],
#  ['OD1668', 'P1168', 'Home', '1853', '5', '0', '2.9'],
#  ['OD1669', 'P1169', 'Fashion', '2080', '5', '15', '2.4'],
#  ['OD1670', 'P1170', 'Fashion', '624', '1', '5', '3.9'],
#  ['OD1671', 'P1171', 'Beauty', '944', '2', '0', '4.4'],
#  ['OD1672', 'P1172', 'Grocery', '308', '1', '20', '1.9'],
#  ['OD1673', 'P1173', 'Grocery', '47', '2', '10', '1.3'],
#  ['OD1674', 'P1174', 'Electronics', '45129', '1', '0', '3.5'],
#  ['OD1675', 'P1175', 'Grocery', '513', '2', '0', '2.7'],
#  ['OD1676', 'P1176', 'Electronics', '18421', '1', '5', '1.4'],
#  ['OD1677', 'P1177', 'Grocery', '163', '3', '20', '4.0'],
#  ['OD1678', 'P1178', 'Grocery', '607', '4', '10', '2.8'],
#  ['OD1679', 'P1179', 'Electronics', '2227', '3', '30', '3.0'],
#  ['OD1680', 'P1180', 'Electronics', '43539', '5', '15', '3.2'],
#  ['OD1681', 'P1181', 'Grocery', '87', '4', '25', '1.1'],
#  ['OD1682', 'P1182', 'Fashion', '2991', '5', '30', '4.5'],
#  ['OD1683', 'P1183', 'Electronics', '15439', '3', '20', '2.8'],
#  ['OD1684', 'P1184', 'Electronics', '18989', '4', '5', '3.2'],
#  ['OD1685', 'P1185', 'Home', '2213', '1', '25', '2.4'],
#  ['OD1686', 'P1186', 'Grocery', '63', '1', '5', '3.0'],
#  ['OD1687', 'P1187', 'Home', '15895', '1', '10', '2.5'],
#  ['OD1688', 'P1188', 'Electronics', '33158', '5', '10', '1.8'],
#  ['OD1689', 'P1189', 'Fashion', '2515', '2', '15', '4.2'],
#  ['OD1690', 'P1190', 'Fashion', '2411', '5', '20', '2.2'],
#  ['OD1691', 'P1191', 'Grocery', '924', '2', '5', '2.8'],
#  ['OD1692', 'P1192', 'Electronics', '20409', '4', '5', '2.3'],
#  ['OD1693', 'P1193', 'Electronics', '7030', '5', '10', '4.6'],
#  ['OD1694', 'P1194', 'Grocery', '894', '1', '15', '1.8'],
#  ['OD1695', 'P1195', 'Fashion', '812', '4', '10', '2.3'],
#  ['OD1696', 'P1196', 'Home', '7233', '3', '0', '4.2'],
#  ['OD1697', 'P1197', 'Grocery', '833', '1', '30', '2.9'],
#  ['OD1698', 'P1198', 'Home', '17153', '5', '5', '1.7'],
#  ['OD1699', 'P1199', 'Fashion', '1325', '2', '30', '3.6'],
#  ['OD1700', 'P1200', 'Home', '16254', '5', '0', '1.4'],
#  ['OD1701', 'P1201', 'Electronics', '27319', '1', '15', '4.6'],
#  ['OD1702', 'P1202', 'Electronics', '23672', '3', '20', '2.3'],
#  ['OD1703', 'P1203', 'Home', '16748', '4', '25', '3.2'],
#  ['OD1704', 'P1204', 'Electronics', '31430', '4', '15', '5.0'],
#  ['OD1705', 'P1205', 'Electronics', '22453', '4', '15', '2.3'],
#  ['OD1706', 'P1206', 'Fashion', '1449', '3', '15', '2.3'],
#  ['OD1707', 'P1207', 'Grocery', '296', '4', '5', '1.4'],
#  ['OD1708', 'P1208', 'Beauty', '1030', '3', '15', '4.6'],
#  ['OD1709', 'P1209', 'Home', '6550', '2', '5', '3.5'],
#  ['OD1710', 'P1210', 'Fashion', '2526', '1', '20', '4.2'],
#  ['OD1711', 'P1211', 'Grocery', '881', '3', '10', '1.1'],
#  ['OD1712', 'P1212', 'Home', '1189', '3', '15', '3.7'],
#  ['OD1713', 'P1213', 'Beauty', '2551', '1', '15', '1.9'],
#  ['OD1714', 'P1214', 'Electronics', '21947', '3', '15', '4.5'],
#  ['OD1715', 'P1215', 'Beauty', '1888', '5', '10', '4.1'],
#  ['OD1716', 'P1216', 'Fashion', '1148', '4', '25', '4.6'],
#  ['OD1717', 'P1217', 'Electronics', '24452', '1', '10', '1.2'],
#  ['OD1718', 'P1218', 'Home', '10549', '3', '0', '4.5'],
#  ['OD1719', 'P1219', 'Fashion', '2466', '3', '10', '2.6'],
#  ['OD1720', 'P1220', 'Electronics', '7201', '4', '20', '3.2'],
#  ['OD1721', 'P1221', 'Books', '645', '3', '25', '4.2'],
#  ['OD1722', 'P1222', 'Beauty', '1580', '4', '0', '1.2'],
#  ['OD1723', 'P1223', 'Electronics', '23883', '2', '25', '2.1'],
#  ['OD1724', 'P1224', 'Books', '181', '3', '10', '4.0'],
#  ['OD1725', 'P1225', 'Beauty', '2381', '4', '20', '4.9'],
#  ['OD1726', 'P1226', 'Grocery', '82', '1', '10', '3.5'],
#  ['OD1727', 'P1227', 'Grocery', '652', '4', '10', '4.5'],
#  ['OD1728', 'P1228', 'Electronics', '4993', '5', '20', '1.3'],
#  ['OD1729', 'P1229', 'Fashion', '2712', '1', '0', '2.9'],
#  ['OD1730', 'P1230', 'Electronics', '47692', '3', '20', '2.2'],
#  ['OD1731', 'P1231', 'Electronics', '33198', '1', '15', '1.3'],
#  ['OD1732', 'P1232', 'Electronics', '15349', '1', '20', '3.4'],
#  ['OD1733', 'P1233', 'Beauty', '1705', '5', '25', '4.2'],
#  ['OD1734', 'P1234', 'Fashion', '1893', '4', '10', '2.1'],
#  ['OD1735', 'P1235', 'Beauty', '543', '2', '20', '3.1'],
#  ['OD1736', 'P1236', 'Grocery', '344', '4', '20', '3.4'],
#  ['OD1737', 'P1237', 'Fashion', '2244', '1', '20', '1.1'],
#  ['OD1738', 'P1238', 'Grocery', '54', '1', '5', '4.5'],
#  ['OD1739', 'P1239', 'Grocery', '84', '5', '30', '2.7'],
#  ['OD1740', 'P1240', 'Electronics', '27455', '4', '25', '4.1'],
#  ['OD1741', 'P1241', 'Fashion', '2096', '3', '5', '1.7'],
#  ['OD1742', 'P1242', 'Electronics', '17289', '5', '10', '2.8'],
#  ['OD1743', 'P1243', 'Fashion', '704', '5', '10', '1.9'],
#  ['OD1744', 'P1244', 'Books', '553', '4', '15', '1.9'],
#  ['OD1745', 'P1245', 'Fashion', '2323', '5', '10', '3.6'],
#  ['OD1746', 'P1246', 'Books', '292', '2', '10', '4.0'],
#  ['OD1747', 'P1247', 'Books', '867', '1', '5', '2.4'],
#  ['OD1748', 'P1248', 'Home', '9021', '3', '10', '2.1'],
#  ['OD1749', 'P1249', 'Electronics', '24500', '1', '20', '2.9'],
#  ['OD1750', 'P1250', 'Electronics', '30038', '3', '20', '2.9'],
#  ['OD1751', 'P1251', 'Fashion', '1912', '5', '20', '1.0'],
#  ['OD1752', 'P1252', 'Grocery', '321', '1', '25', '4.3'],
#  ['OD1753', 'P1253', 'Electronics', '29575', '4', '0', '2.4'],
#  ['OD1754', 'P1254', 'Grocery', '360', '5', '0', '1.9'],
#  ['OD1755', 'P1255', 'Electronics', '31837', '3', '25', '4.7'],
#  ['OD1756', 'P1256', 'Electronics', '5963', '5', '0', '3.5'],
#  ['OD1757', 'P1257', 'Home', '955', '5', '10', '4.5'],
#  ['OD1758', 'P1258', 'Fashion', '382', '1', '30', '3.0'],
#  ['OD1759', 'P1259', 'Grocery', '798', '3', '10', '1.5'],
#  ['OD1760', 'P1260', 'Electronics', '44699', '4', '10', '2.6'],
#  ['OD1761', 'P1261', 'Beauty', '505', '5', '20', '2.0'],
#  ['OD1762', 'P1262', 'Fashion', '2692', '1', '20', '3.9'],
#  ['OD1763', 'P1263', 'Fashion', '1187', '2', '20', '1.0'],
#  ['OD1764', 'P1264', 'Fashion', '1058', '5', '30', '1.2'],
#  ['OD1765', 'P1265', 'Electronics', '22690', '4', '5', '2.0'],
#  ['OD1766', 'P1266', 'Fashion', '1547', '1', '30', '3.7'],
#  ['OD1767', 'P1267', 'Electronics', '32902', '4', '15', '4.6'],
#  ['OD1768', 'P1268', 'Grocery', '351', '2', '10', '2.4'],
#  ['OD1769', 'P1269', 'Home', '5989', '5', '0', '3.6'],
#  ['OD1770', 'P1270', 'Books', '917', '3', '20', '1.0'],
#  ['OD1771', 'P1271', 'Electronics', '12997', '3', '25', '1.5'],
#  ['OD1772', 'P1272', 'Electronics', '40986', '4', '10', '3.9'],
#  ['OD1773', 'P1273', 'Electronics', '12277', '5', '25', '4.3'],
#  ['OD1774', 'P1274', 'Electronics', '28497', '2', '0', '3.8'],
#  ['OD1775', 'P1275', 'Books', '366', '3', '10', '2.9'],
#  ['OD1776', 'P1276', 'Electronics', '24864', '2', '20', '1.5'],
#  ['OD1777', 'P1277', 'Electronics', '12836', '1', '30', '4.3'],
#  ['OD1778', 'P1278', 'Home', '7561', '4', '20', '3.8'],
#  ['OD1779', 'P1279', 'Electronics', '35926', '5', '30', '3.2'],
#  ['OD1780', 'P1280', 'Books', '732', '4', '15', '4.2'],
#  ['OD1781', 'P1281', 'Electronics', '18358', '3', '15', '3.3'],
#  ['OD1782', 'P1282', 'Electronics', '3634', '3', '5', '2.5'],
#  ['OD1783', 'P1283', 'Electronics', '1641', '4', '15', '3.8'],
#  ['OD1784', 'P1284', 'Fashion', '878', '2', '15', '2.7'],
#  ['OD1785', 'P1285', 'Electronics', '3767', '5', '0', '2.4'],
#  ['OD1786', 'P1286', 'Grocery', '167', '3', '20', '3.1'],
#  ['OD1787', 'P1287', 'Electronics', '17797', '4', '10', '2.4'],
#  ['OD1788', 'P1288', 'Grocery', '498', '3', '25', '3.4'],
#  ['OD1789', 'P1289', 'Electronics', '11620', '5', '5', '4.4'],
#  ['OD1790', 'P1290', 'Fashion', '1663', '4', '25', '2.8'],
#  ['OD1791', 'P1291', 'Fashion', '1848', '5', '5', '2.9'],
#  ['OD1792', 'P1292', 'Home', '9691', '3', '10', '4.9'],
#  ['OD1793', 'P1293', 'Electronics', '24823', '2', '10', '1.8'],
#  ['OD1794', 'P1294', 'Beauty', '412', '3', '5', '2.6'],
#  ['OD1795', 'P1295', 'Electronics', '19193', '3', '20', '2.8'],
#  ['OD1796', 'P1296', 'Fashion', '741', '2', '20', '4.3'],
#  ['OD1797', 'P1297', 'Fashion', '1772', '2', '15', '2.3'],
#  ['OD1798', 'P1298', 'Books', '185', '4', '5', '4.3'],
#  ['OD1799', 'P1299', 'Fashion', '2616', '5', '20', '3.4'],
#  ['OD1800', 'P1300', 'Electronics', '15473', '4', '0', '2.5'],
#  ['OD1801', 'P1301', 'Home', '7251', '4', '20', '1.6'],
#  ['OD1802', 'P1302', 'Electronics', '2852', '5', '5', '1.7'],
#  ['OD1803', 'P1303', 'Electronics', '21800', '3', '30', '2.8'],
#  ['OD1804', 'P1304', 'Fashion', '1777', '2', '20', '1.8'],
#  ['OD1805', 'P1305', 'Beauty', '390', '4', '20', '4.9'],
#  ['OD1806', 'P1306', 'Fashion', '558', '4', '10', '1.7'],
#  ['OD1807', 'P1307', 'Grocery', '978', '5', '10', '1.6'],
#  ['OD1808', 'P1308', 'Grocery', '885', '3', '15', '2.6'],
#  ['OD1809', 'P1309', 'Electronics', '20054', '4', '5', '3.5'],
#  ['OD1810', 'P1310', 'Home', '14172', '2', '10', '1.8'],
#  ['OD1811', 'P1311', 'Electronics', '49480', '4', '20', '2.9'],
#  ['OD1812', 'P1312', 'Fashion', '2411', '3', '30', '4.9'],
#  ['OD1813', 'P1313', 'Electronics', '1640', '2', '10', '2.4'],
#  ['OD1814', 'P1314', 'Beauty', '2343', '5', '25', '4.2'],
#  ['OD1815', 'P1315', 'Books', '574', '5', '0', '3.7'],
#  ['OD1816', 'P1316', 'Books', '656', '2', '15', '4.9'],
#  ['OD1817', 'P1317', 'Electronics', '1382', '3', '5', '4.9'],
#  ['OD1818', 'P1318', 'Home', '5967', '4', '25', '3.4'],
#  ['OD1819', 'P1319', 'Fashion', '1451', '3', '0', '3.3'],
#  ['OD1820', 'P1320', 'Electronics', '2954', '3', '10', '4.7'],
#  ['OD1821', 'P1321', 'Grocery', '518', '2', '0', '4.5'],
#  ['OD1822', 'P1322', 'Electronics', '48577', '3', '5', '2.8'],
#  ['OD1823', 'P1323', 'Electronics', '22690', '4', '30', '4.8'],
#  ['OD1824', 'P1324', 'Fashion', '2758', '1', '15', '1.0'],
#  ['OD1825', 'P1325', 'Fashion', '2584', '1', '0', '4.6'],
#  ['OD1826', 'P1326', 'Beauty', '2244', '3', '10', '1.1'],
#  ['OD1827', 'P1327', 'Books', '592', '5', '30', '3.9'],
#  ['OD1828', 'P1328', 'Fashion', '1337', '5', '25', '3.9'],
#  ['OD1829', 'P1329', 'Electronics', '19837', '2', '25', '3.6'],
#  ['OD1830', 'P1330', 'Books', '302', '2', '0', '2.1'],
#  ['OD1831', 'P1331', 'Fashion', '895', '1', '25', '1.0'],
#  ['OD1832', 'P1332', 'Fashion', '218', '2', '5', '4.3'],
#  ['OD1833', 'P1333', 'Electronics', '12090', '3', '0', '2.4'],
#  ['OD1834', 'P1334', 'Electronics', '10264', '1', '30', '1.6'],
#  ['OD1835', 'P1335', 'Fashion', '1967', '5', '15', '3.6'],
#  ['OD1836', 'P1336', 'Beauty', '306', '4', '10', '3.5'],
#  ['OD1837', 'P1337', 'Beauty', '851', '4', '25', '1.1'],
#  ['OD1838', 'P1338', 'Grocery', '94', '3', '10', '3.5'],
#  ['OD1839', 'P1339', 'Books', '783', '2', '20', '4.8'],
#  ['OD1840', 'P1340', 'Electronics', '38510', '2', '0', '3.0'],
#  ['OD1841', 'P1341', 'Home', '7923', '4', '5', '1.3'],
#  ['OD1842', 'P1342', 'Electronics', '46592', '4', '5', '2.1'],
#  ['OD1843', 'P1343', 'Fashion', '1438', '3', '25', '2.3'],
#  ['OD1844', 'P1344', 'Grocery', '584', '1', '0', '3.6'],
#  ['OD1845', 'P1345', 'Home', '536', '5', '20', '1.9'],
#  ['OD1846', 'P1346', 'Fashion', '1504', '1', '30', '3.0'],
#  ['OD1847', 'P1347', 'Books', '544', '2', '5', '4.3'],
#  ['OD1848', 'P1348', 'Grocery', '585', '4', '15', '3.7'],
#  ['OD1849', 'P1349', 'Grocery', '33', '2', '15', '1.9'],
#  ['OD1850', 'P1350', 'Fashion', '252', '4', '20', '4.7'],
#  ['OD1851', 'P1351', 'Fashion', '1689', '4', '30', '1.6'],
#  ['OD1852', 'P1352', 'Electronics', '16149', '2', '5', '3.9'],
#  ['OD1853', 'P1353', 'Grocery', '892', '4', '0', '2.3'],
#  ['OD1854', 'P1354', 'Fashion', '1190', '1', '5', '4.1'],
#  ['OD1855', 'P1355', 'Electronics', '3667', '1', '30', '3.3'],
#  ['OD1856', 'P1356', 'Fashion', '1999', '1', '25', '2.0'],
#  ['OD1857', 'P1357', 'Electronics', '5776', '4', '10', '4.3'],
#  ['OD1858', 'P1358', 'Home', '5838', '3', '0', '4.4'],
#  ['OD1859', 'P1359', 'Electronics', '37791', '4', '15', '4.6'],
#  ['OD1860', 'P1360', 'Fashion', '1018', '5', '10', '4.6'],
#  ['OD1861', 'P1361', 'Fashion', '2871', '4', '10', '1.4'],
#  ['OD1862', 'P1362', 'Electronics', '32941', '2', '20', '2.6'],
#  ['OD1863', 'P1363', 'Electronics', '27086', '1', '30', '1.0'],
#  ['OD1864', 'P1364', 'Fashion', '222', '5', '20', '4.5'],
#  ['OD1865', 'P1365', 'Electronics', '30296', '1', '15', '1.5'],
#  ['OD1866', 'P1366', 'Books', '550', '1', '25', '2.1'],
#  ['OD1867', 'P1367', 'Electronics', '16711', '3', '10', '3.6'],
#  ['OD1868', 'P1368', 'Electronics', '46468', '5', '25', '4.8'],
#  ['OD1869', 'P1369', 'Home', '19071', '1', '10', '2.8'],
#  ['OD1870', 'P1370', 'Electronics', '22661', '3', '15', '1.0'],
#  ['OD1871', 'P1371', 'Electronics', '38842', '1', '20', '2.7'],
#  ['OD1872', 'P1372', 'Fashion', '596', '4', '30', '3.9'],
#  ['OD1873', 'P1373', 'Fashion', '848', '1', '25', '2.9'],
#  ['OD1874', 'P1374', 'Home', '2105', '1', '15', '3.7'],
#  ['OD1875', 'P1375', 'Fashion', '1396', '5', '5', '2.6'],
#  ['OD1876', 'P1376', 'Electronics', '25851', '4', '5', '3.9'],
#  ['OD1877', 'P1377', 'Books', '424', '4', '15', '2.6'],
#  ['OD1878', 'P1378', 'Home', '14923', '1', '15', '1.3'],
#  ['OD1879', 'P1379', 'Home', '334', '3', '20', '1.2'],
#  ['OD1880', 'P1380', 'Fashion', '317', '2', '20', '2.1'],
#  ['OD1881', 'P1381', 'Beauty', '2150', '2', '25', '2.0'],
#  ['OD1882', 'P1382', 'Home', '19657', '2', '25', '3.8'],
#  ['OD1883', 'P1383', 'Books', '496', '2', '10', '3.0'],
#  ['OD1884', 'P1384', 'Books', '209', '1', '15', '3.4'],
#  ['OD1885', 'P1385', 'Books', '634', '5', '10', '4.5'],
#  ['OD1886', 'P1386', 'Grocery', '397', '4', '5', '3.7'],
#  ['OD1887', 'P1387', 'Electronics', '20807', '4', '30', '1.9'],
#  ['OD1888', 'P1388', 'Beauty', '2795', '4', '10', '3.3'],
#  ['OD1889', 'P1389', 'Electronics', '6318', '1', '5', '1.7'],
#  ['OD1890', 'P1390', 'Fashion', '1959', '5', '0', '4.1'],
#  ['OD1891', 'P1391', 'Books', '617', '4', '0', '2.5'],
#  ['OD1892', 'P1392', 'Grocery', '547', '3', '20', '3.6'],
#  ['OD1893', 'P1393', 'Home', '18691', '3', '0', '3.4'],
#  ['OD1894', 'P1394', 'Home', '13867', '5', '25', '1.6'],
#  ['OD1895', 'P1395', 'Electronics', '46171', '3', '20', '1.9'],
#  ['OD1896', 'P1396', 'Electronics', '27733', '2', '15', '2.9'],
#  ['OD1897', 'P1397', 'Beauty', '1197', '4', '5', '3.3'],
#  ['OD1898', 'P1398', 'Electronics', '22107', '1', '30', '4.1'],
#  ['OD1899', 'P1399', 'Home', '10947', '4', '5', '3.6'],
#  ['OD1900', 'P1400', 'Electronics', '49929', '1', '0', '1.9'],
#  ['OD1901', 'P1401', 'Fashion', '2609', '1', '5', '4.4'],
#  ['OD1902', 'P1402', 'Electronics', '31726', '5', '10', '1.6'],
#  ['OD1903', 'P1403', 'Home', '13479', '4', '10', '2.0'],
#  ['OD1904', 'P1404', 'Books', '147', '4', '25', '2.2'],
#  ['OD1905', 'P1405', 'Fashion', '1923', '1', '30', '1.2'],
#  ['OD1906', 'P1406', 'Home', '3413', '2', '0', '4.7'],
#  ['OD1907', 'P1407', 'Electronics', '6439', '1', '10', '1.2'],
#  ['OD1908', 'P1408', 'Electronics', '34964', '2', '25', '3.1'],
#  ['OD1909', 'P1409', 'Grocery', '34', '5', '5', '3.7'],
#  ['OD1910', 'P1410', 'Grocery', '472', '2', '25', '3.2'],
#  ['OD1911', 'P1411', 'Grocery', '928', '3', '25', '4.5'],
#  ['OD1912', 'P1412', 'Grocery', '539', '4', '20', '1.2'],
#  ['OD1913', 'P1413', 'Beauty', '2428', '5', '5', '4.4'],
#  ['OD1914', 'P1414', 'Fashion', '1891', '4', '25', '1.4'],
#  ['OD1915', 'P1415', 'Electronics', '13367', '3', '15', '5.0'],
#  ['OD1916', 'P1416', 'Electronics', '31027', '3', '5', '3.1'],
#  ['OD1917', 'P1417', 'Fashion', '1555', '3', '20', '2.7'],
#  ['OD1918', 'P1418', 'Electronics', '40454', '2', '5', '1.1'],
#  ['OD1919', 'P1419', 'Fashion', '819', '3', '20', '4.6'],
#  ['OD1920', 'P1420', 'Electronics', '28501', '1', '10', '2.6'],
#  ['OD1921', 'P1421', 'Home', '2995', '2', '5', '4.0'],
#  ['OD1922', 'P1422', 'Electronics', '20096', '2', '25', '3.9'],
#  ['OD1923', 'P1423', 'Fashion', '694', '1', '10', '3.7'],
#  ['OD1924', 'P1424', 'Fashion', '386', '4', '5', '4.1'],
#  ['OD1925', 'P1425', 'Electronics', '41545', '4', '0', '4.3'],
#  ['OD1926', 'P1426', 'Electronics', '18520', '4', '15', '1.9'],
#  ['OD1927', 'P1427', 'Electronics', '43678', '5', '5', '2.3'],
#  ['OD1928', 'P1428', 'Fashion', '2569', '3', '25', '2.7'],
#  ['OD1929', 'P1429', 'Home', '11228', '5', '10', '4.6'],
#  ['OD1930', 'P1430', 'Electronics', '1696', '2', '15', '2.2'],
#  ['OD1931', 'P1431', 'Electronics', '41195', '3', '5', '5.0'],
#  ['OD1932', 'P1432', 'Fashion', '800', '5', '30', '2.5'],
#  ['OD1933', 'P1433', 'Electronics', '9671', '4', '20', '1.1'],
#  ['OD1934', 'P1434', 'Fashion', '2965', '1', '5', '5.0'],
#  ['OD1935', 'P1435', 'Books', '959', '4', '20', '2.4'],
#  ['OD1936', 'P1436', 'Fashion', '2571', '1', '5', '4.6'],
#  ['OD1937', 'P1437', 'Electronics', '25229', '5', '15', '1.4'],
#  ['OD1938', 'P1438', 'Fashion', '1489', '3', '10', '4.0'],
#  ['OD1939', 'P1439', 'Fashion', '2124', '2', '0', '1.7'],
#  ['OD1940', 'P1440', 'Home', '10693', '5', '0', '4.8'],
#  ['OD1941', 'P1441', 'Fashion', '908', '3', '10', '2.7'],
#  ['OD1942', 'P1442', 'Fashion', '2835', '2', '10', '2.1'],
#  ['OD1943', 'P1443', 'Home', '799', '2', '20', '2.7'],
#  ['OD1944', 'P1444', 'Books', '230', '2', '15', '3.0'],
#  ['OD1945', 'P1445', 'Grocery', '647', '5', '20', '2.0'],
#  ['OD1946', 'P1446', 'Beauty', '1441', '3', '30', '1.1'],
#  ['OD1947', 'P1447', 'Grocery', '513', '1', '10', '1.3'],
#  ['OD1948', 'P1448', 'Fashion', '470', '3', '20', '2.8'],
#  ['OD1949', 'P1449', 'Electronics', '26466', '3', '30', '2.3'],
#  ['OD1950', 'P1450', 'Fashion', '1193', '5', '5', '4.3'],
#  ['OD1951', 'P1451', 'Grocery', '309', '1', '0', '3.2'],
#  ['OD1952', 'P1452', 'Fashion', '2875', '5', '20', '2.6'],
#  ['OD1953', 'P1453', 'Fashion', '380', '1', '0', '3.4'],
#  ['OD1954', 'P1454', 'Electronics', '25775', '5', '0', '4.9'],
#  ['OD1955', 'P1455', 'Books', '489', '5', '20', '2.7'],
#  ['OD1956', 'P1456', 'Home', '5910', '4', '15', '2.2'],
#  ['OD1957', 'P1457', 'Fashion', '1734', '4', '30', '2.7'],
#  ['OD1958', 'P1458', 'Fashion', '2132', '2', '5', '4.6'],
#  ['OD1959', 'P1459', 'Fashion', '1068', '1', '10', '2.1'],
#  ['OD1960', 'P1460', 'Grocery', '204', '3', '30', '4.2'],
#  ['OD1961', 'P1461', 'Home', '11914', '5', '25', '3.4'],
#  ['OD1962', 'P1462', 'Electronics', '15588', '3', '30', '3.2'],
#  ['OD1963', 'P1463', 'Electronics', '3773', '3', '5', '4.1'],
#  ['OD1964', 'P1464', 'Fashion', '720', '1', '10', '3.5'],
#  ['OD1965', 'P1465', 'Grocery', '745', '1', '0', '3.4'],
#  ['OD1966', 'P1466', 'Grocery', '455', '1', '10', '4.0'],
#  ['OD1967', 'P1467', 'Fashion', '3000', '1', '30', '3.0'],
#  ['OD1968', 'P1468', 'Electronics', '12567', '1', '0', '2.8'],
#  ['OD1969', 'P1469', 'Fashion', '303', '3', '25', '4.7'],
#  ['OD1970', 'P1470', 'Fashion', '606', '2', '30', '4.4'],
#  ['OD1971', 'P1471', 'Electronics', '36932', '2', '10', '1.2'],
#  ['OD1972', 'P1472', 'Electronics', '19004', '5', '25', '2.3'],
#  ['OD1973', 'P1473', 'Fashion', '1531', '5', '10', '1.5'],
#  ['OD1974', 'P1474', 'Electronics', '42020', '4', '30', '2.7'],
#  ['OD1975', 'P1475', 'Grocery', '211', '1', '0', '2.5'],
#  ['OD1976', 'P1476', 'Grocery', '802', '4', '15', '2.5'],
#  ['OD1977', 'P1477', 'Grocery', '870', '3', '15', '1.5'],
#  ['OD1978', 'P1478', 'Books', '176', '2', '0', '4.9'],
#  ['OD1979', 'P1479', 'Home', '4896', '4', '10', '3.0'],
#  ['OD1980', 'P1480', 'Fashion', '1101', '1', '0', '4.9'],
#  ['OD1981', 'P1481', 'Grocery', '358', '5', '0', '2.2'],
#  ['OD1982', 'P1482', 'Electronics', '44867', '5', '25', '3.2'],
#  ['OD1983', 'P1483', 'Beauty', '2813', '3', '10', '4.5'],
#  ['OD1984', 'P1484', 'Fashion', '651', '4', '30', '2.3'],
#  ['OD1985', 'P1485', 'Beauty', '932', '1', '20', '1.3'],
#  ['OD1986', 'P1486', 'Electronics', '49579', '3', '5', '4.3'],
#  ['OD1987', 'P1487', 'Books', '693', '3', '5', '2.0'],
#  ['OD1988', 'P1488', 'Fashion', '312', '4', '25', '2.6'],
#  ['OD1989', 'P1489', 'Beauty', '1974', '3', '15', '3.5'],
#  ['OD1990', 'P1490', 'Electronics', '20052', '5', '0', '4.5'],
#  ['OD1991', 'P1491', 'Fashion', '2365', '3', '0', '2.1'],
#  ['OD1992', 'P1492', 'Fashion', '218', '5', '10', '1.2'],
#  ['OD1993', 'P1493', 'Fashion', '2806', '4', '0', '3.6'],
#  ['OD1994', 'P1494', 'Home', '3865', '3', '25', '3.4'],
#  ['OD1995', 'P1495', 'Beauty', '2501', '5', '5', '4.8'],
#  ['OD1996', 'P1496', 'Books', '459', '1', '5', '2.8'],
#  ['OD1997', 'P1497', 'Electronics', '33469', '1', '5', '4.9'],
#  ['OD1998', 'P1498', 'Beauty', '1398', '4', '25', '3.2'],
#  ['OD1999', 'P1499', 'Home', '15541', '2', '15', '2.7']]

# %% [markdown]
# #**Load into NumPy**

# %% [markdown]
# **STEP 1: Extract price column**

# %%
prices = np.array([int(row[3]) for row in data])

# %% [markdown]
# **STEP 2: Extract quantity**

# %%
quanity = np.array([int(row[4]) for row in data])

# %% [markdown]
# **STEP 3: Extract discount**

# %%
discount = np.array([int(row[5]) for row in data])

# %% [markdown]
# **STEP 4: Extract rating**

# %%
rating = np.array([float(row[6]) for row in data])

# %% [markdown]
# **STEP 5: Extract category**

# %%
categories = np.array([row[2] for row in data])

# %% [markdown]
# #**Revenue Calculations**

# %% [markdown]
# **STEP 1: Basic revenue**

# %%
revenue = prices * quanity

# %% [markdown]
# **STEP 2: Apply discount**

# %%
final_prices = prices * (1 - (discount/100))
final_revenue = final_prices * quanity

# %% [markdown]
# #**Filtering**

# %% [markdown]
# **A. HIGH RATING ORDERS (>4.5)**

# %%
high_rating_mask = rating >= 4.5
high_rating_orders = final_revenue[high_rating_mask]

# %% [markdown]
# **B. Electronics category only**

# %%
elec_mask = categories == "Electronics"
electronics_orders = final_revenue[elec_mask]
electronics_orders
# Out:
# array([158312.  ,   9385.6 ,  88061.4 ,   8279.85,  74924.1 ,  48136.  ,
#         34801.2 ,   6822.9 ,  30955.5 , 144648.  ,  41821.7 ,   5227.2 ,
#         23283.2 ,  47644.  ,   8189.  ,  26830.25,  63745.5 , 189040.  ,
#         73852.8 ,  37893.  , 164940.  , 171640.  ,  40556.  ,  69354.  ,
#         11341.8 ,  25758.  ,  26415.7 ,  64762.5 ,  50681.6 ,  94345.75,
#         55472.4 ,  37340.  ,  99024.  ,  69960.  ,  71668.  ,  33582.5 ,
#         50311.5 ,  20440.8 ,   5526.  ,  46153.6 ,  86673.6 , 170986.5 ,
#        107154.3 ,   9699.5 ,  45261.8 , 137310.  , 130368.  ,  34799.  ,
#        184960.  ,  94765.5 ,  62877.9 ,  82701.  ,  58303.2 ,  32427.2 ,
#        118756.  ,  52335.  ,  84758.4 ,  22449.  ,  38126.  ,  57115.8 ,
#         13661.25,  22758.75,  33790.5 ,  55606.5 , 183660.  ,  87681.6 ,
#         88353.75,  69484.8 , 228310.  ,  11814.6 , 125241.6 ,  64349.1 ,
#        199108.  ,  81301.  ,  37283.7 , 104193.75, 152396.5 ,  17137.5 ,
#         25565.4 ,  17744.4 ,   7224.  ,  25986.  , 158745.  ,  24024.  ,
#         17619.  ,  79370.  ,  77472.  ,  61616.  , 120700.8 ,  78454.  ,
#         33681.75,  33620.25,  48023.  , 105030.8 ,   8051.4 ,  73640.2 ,
#         36599.7 ,  44539.  ,  99882.3 ,  82418.55,  24957.8 ,  74394.  ,
#        135596.8 , 177444.  ,  36194.05,  54567.  ,  78780.  ,   2024.  ,
#        121741.25,  34736.1 ,  35391.3 ,  85488.75,  27941.4 ,  20263.6 ,
#         16128.  ,  42711.  ,   2194.5 ,  37755.2 ,  32880.  , 196982.5 ,
#         27254.5 , 180229.25, 125568.9 ,  17196.9 ,  20854.4 , 142600.  ,
#          6429.75,  94327.4 , 141798.  , 152704.2 ,  27960.  ,  13470.8 ,
#         68811.4 ,  33205.25,  41920.8 ,  40633.5 ,  18972.9 ,  46667.  ,
#         16365.9 ,  89740.8 ,  25189.25,  29670.9 ,  34643.2 ,  18480.  ,
#         90731.25,  11766.3 ,  59358.6 ,  36980.1 ,  37300.8 ,  27444.8 ,
#        125242.4 ,  41674.  ,  41790.4 ,  27320.4 , 198241.25, 150832.  ,
#         56392.  ,  18102.6 , 116667.  ,  94530.  ,  76528.2 , 140675.2 ,
#        141907.2 , 193273.  , 138272.  ,  12693.1 , 147423.5 ,  71477.7 ,
#         69291.6 ,  58450.5 ,  40222.  ,  26971.2 , 192224.  ,  39138.  ,
#         74170.8 ,  10051.2 ,  70577.4 ,  52641.  ,  20579.85,  27094.4 ,
#         86826.  ,  20222.35,  83342.  ,  44700.  ,  20655.  , 134665.5 ,
#        136120.  , 114210.  ,  16888.5 ,  49901.6 ,  36972.  ,  40221.1 ,
#        150369.8 ,  41869.3 , 132990.  , 150355.2 ,  83642.  ,  51996.  ,
#         23110.4 ,  78227.1 , 137196.15,  64988.7 ,  68432.4 , 230785.  ,
#        107895.  ,  46119.6 ,  36120.75,  11652.  ,  20863.5 ,  31485.  ,
#         57543.  , 201414.25,  45129.  ,  17499.95,   4676.7 , 185040.75,
#         37053.6 ,  72158.2 , 149211.  ,  77554.2 ,  31635.  ,  23221.15,
#         56812.8 , 106862.  ,  76340.2 ,  55964.85,  22006.8 ,  23043.2 ,
#         35824.5 ,  19972.  , 114460.8 ,  28218.3 ,  12279.2 ,  82365.  ,
#         77800.5 ,  19600.  ,  72091.2 , 118300.  ,  71633.25,  29815.  ,
#        160916.4 ,  86222.  , 111866.8 ,  29243.25, 147549.6 ,  46038.75,
#         56994.  ,  39782.4 ,   8985.2 , 125741.  ,  46812.9 ,  10356.9 ,
#          5579.4 ,  18835.  ,  64069.2 ,  55195.  ,  44681.4 ,  46063.2 ,
#         61892.  ,  13547.  ,  45780.  ,  76205.2 , 158336.  ,   2952.  ,
#          3938.7 ,   7975.8 , 138444.45,  63532.  ,  29755.5 ,  36270.  ,
#          7184.8 ,  77020.  , 177049.6 ,  30683.1 ,   2566.9 ,  20793.6 ,
#        128489.4 ,  52705.6 ,  18960.2 ,  25751.6 ,  45119.7 , 174255.  ,
#         57785.55,  31073.6 ,  98233.8 ,  58259.6 ,   6002.1 , 110810.4 ,
#         47146.1 ,  15474.9 ,  49929.  , 142767.  ,   5795.1 ,  52446.  ,
#         34085.85,  88426.95,  76862.6 ,  25650.9 ,  30144.  , 166180.  ,
#         62968.  , 207470.5 ,   2883.2 , 117405.75,  30947.2 , 107223.25,
#         55578.6 , 128875.  ,  32734.8 ,  10753.05,  12567.  ,  66477.6 ,
#         71265.  , 117656.  , 168251.25, 141300.15, 100260.  ,  31795.55])

# %% [markdown]
# #**Category-Level Analytics**

# %% [markdown]
# **STEP 1: Find unique categories**

# %%
unique_cats = np.unique(categories)

# %% [markdown]
# **STEP 2: Compute metrics for each category**

# %%
for cat in unique_cats:
    mask = categories == cat
    avg_price = prices[mask].mean()
    total_rev = final_revenue[mask].sum()
    count = mask.sum()

    print(cat)
    print(avg_price)
    print(total_rev)
    print(count)
# Out:
# Beauty
# 1509.0357142857142
# 239815.05
# 56
# Books
# 482.0744680851064
# 107603.55
# 94
# Electronics
# 26159.764150943396
# 21415971.75
# 318
# Fashion
# 1569.1593625498008
# 948838.6
# 251
# Grocery
# 466.3
# 156957.85
# 140
# Home
# 9482.687943262412
# 3935162.5
# 141

# %% [markdown]
# **Outlier Detection (Data Quality Step)**

# %%
mean_r = final_revenue.mean()
std_r = final_revenue.std()

outliers = final_revenue[
	(final_revenue > mean_r + 3*std_r) |
	(final_revenue < mean_r - 3*std_r)
]

# %% [markdown]
# **Save Clean Data (Export Final CSV)**

# %% [markdown]
# **Create final matrix:**

# %%
clean_matrix = np.column_stack((final_prices, final_revenue, rating))

# %% [markdown]
# **Save it:**

# %%
np.savetxt("amazon_cleaned.csv",
           clean_matrix,
           delimiter=",",
           fmt="%.2f",
           header="Final_Price, Final_Revenue, Ratings",
           comments="")
