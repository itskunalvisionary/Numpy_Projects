# %% [markdown]
# # **📌 PROJECT 1 — Apple iPhone Weekly Temperature Analysis**

# %% [markdown]
# **Apple records CPU temperature of iPhones every hour for 24 hours:**

# %% [markdown]
# # Tasks:
#
# Convert to NumPy array
#
# Slice morning temps (5am–11am)
#
# Slice evening temps (5pm–11pm)
#
# Extract temps above 42°C
#
# Count overheating hours

# %%
#Apple records CPU temperature of iPhones every hour for 24 hours:

temps = [
38.1, 39.5, 40.2, 41.1, 42.3, 43.0, 44.4, 45.1,
41.3, 39.9, 38.7, 36.8, 35.8, 34.5, 33.8, 34.4,
36.2, 37.5, 38.9, 40.1, 41.0, 42.5, 44.0, 45.3
]

# %% [markdown]
# **1. Convert to NumPy**

# %%
import numpy as np
temps_array = np.array(temps)
temps_array
# Out:
# array([38.1, 39.5, 40.2, 41.1, 42.3, 43. , 44.4, 45.1, 41.3, 39.9, 38.7,
#        36.8, 35.8, 34.5, 33.8, 34.4, 36.2, 37.5, 38.9, 40.1, 41. , 42.5,
#        44. , 45.3])

# %% [markdown]
# **2. Morning temps (5am–11am)**

# %%
morning = temps_array[5:12]
morning
# Out:
# array([43. , 44.4, 45.1, 41.3, 39.9, 38.7, 36.8])

# %% [markdown]
# **3. Evening temps (5pm–11pm)**

# %%
evening = temps_array[17:24]
evening
# Out:
# array([37.5, 38.9, 40.1, 41. , 42.5, 44. , 45.3])

# %% [markdown]
# **Extract temps above 42°C**

# %%
hot = temps_array[temps_array>42]
hot
# Out:
# array([42.3, 43. , 44.4, 45.1, 42.5, 44. , 45.3])

# %% [markdown]
# **5. Count overheating**

# %%
count_overheating = np.sum(temps_array>42)
count_overheating
# Out:
# np.int64(7)
