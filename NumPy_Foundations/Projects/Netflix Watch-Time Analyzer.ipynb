# %% [markdown]
# # **📌 PROJECT 2 — Netflix Watch-Time Analyzer (Basic Version)**

# %% [markdown]
# **Dataset: watch-time in minutes for 14 days:**

# %% [markdown]
# # **Tasks**
#
# Convert to NumPy
#
# Extract weekend (last 2 days)
#
# Extract binge-watching days > 100 mins
#
# Extract low-activity days < 40 mins
#
# Find average weekday watch time

# %%
watch = [45, 60, 55, 120, 150, 30, 40, 75, 100, 90, 50, 30, 20, 200]

# %% [markdown]
# **Convert to NumPy**

# %%
import numpy as np
watch_arr = np.array(watch)
type(watch_arr)
# Out:
# numpy.ndarray

# %% [markdown]
# **Extract weekend (last 2 days)**

# %%
weekend = watch_arr[-2:]
weekend
# Out:
# array([ 20, 200])

# %% [markdown]
# **Extract binge-watching days > 100 mins**

# %%
bing = watch_arr[watch_arr>=100]
bing
# Out:
# array([120, 150, 100, 200])

# %% [markdown]
# **Extract low-activity days < 40 mins**

# %%
low = watch_arr[watch_arr<=40]
low
# Out:
# array([30, 40, 30, 20])

# %% [markdown]
# **Find average weekday watch time**

# %%
watch_time_avg = np.mean(watch_arr[:12])
print(watch_time_avg)
print(round(watch_time_avg,2))
# Out:
# 70.41666666666667
# 70.42
